# %% [markdown]
# # 구내식당 식수 인원 예측 AI 경진대회
# ## 7조
#
# [데이터 출처: DACON](https://dacon.io/competitions/official/235743/overview/description)

# %% [markdown]
# # 개요
#
# ### 데이터
#
# - 구내식당 데이터셋
# - 구내식당의 요일별 점심, 저녁식사를 먹는 인원을 예측
# - 빅데이터 분석을 활용한 정확도 높은 예측을 통해 잔반 발생량의 획기적 감소 목적

# %% [markdown]
# ### 데이터 특성 구분
#
# - `일자`: 년-월-일 로 구성되어 있는 날짜
# - `요일` : 주말을 제외한 평일로 구성되어 있는 요일
# - `본사정원수` : 회사의 총 근무 직원 수
# - `본사휴가자수` : 해당 근무 일자 중 휴가 직원 수
# - `본사출장자수` : 해당 근무 일자 중 출장 중인 직원 수
# - `시간외근무명령서승인건수`
# - `현본사소속재택근무자수`
# - `조식메뉴` : 밥, 국, 반찬 등으로 구성된 조식 메뉴
# - `중식메뉴` : 밥, 국, 반찬 등으로 구성된 중식 메뉴
# - `석식메뉴` : 밥, 국, 반찬 등으로 구성된 석식 메뉴
# - `중식계` : 해당 일자 중식을 먹은 직원의 계
# - `석식계` : 해당 일자 석식을 먹은 직원의 계

# %% [markdown]
# ### 라이브러리 및 데이터 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import koreanize_matplotlib

# %%
def split_train_test(data, test_ratio=0.2, suffle=True):
    if test_ratio >= 1:
        raise ValueError("test_ratio is must be less than 1")
        
    if suffle:
        suffled_indices = np.random.permutation(len(data))
        test_set_size = int(len(data) * test_ratio)
        test_indices = suffled_indices[:test_set_size]
        train_indices = suffled_indices[test_set_size:]
        return data.iloc[train_indices], data.iloc[test_indices]
    else:
        train_set_size = int(len(data) * (1 - test_ratio))
        return data.iloc[:train_set_size], data.iloc[train_set_size:]

# %%
BASE_PATH = "data/"

# %%
original_df= pd.read_csv(BASE_PATH + "/train.csv")

# %% [markdown]
# 1차적으로 ```train``` / ```test``` 분리

# %%
train, test = split_train_test(original_df, suffle=False)
display(train.head(2))
train.shape, test.shape
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0
# ((964, 12), (241, 12))

# %%
y_test = pd.DataFrame(test.pop("중식계"))
y_test["석식계"] = test.pop("석식계")
display(test.head(2))
test.shape
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 964  2020-01-14  화   2821      96     236             388          0.0
# 965  2020-01-15  수   2821      97     235               4          0.0
#
#                                                   조식메뉴  \
# 964  모닝롤/바나나샌드  우유/주스 스크램블에그 흑임자죽/쌀밥 (쌀:국내산) 감자양파국 ...
# 965  모닝롤/치즈프레즐  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 차돌박이찌개 ...
#
#                                                   중식메뉴  \
# 964  쌀밥/잡곡밥 (쌀:국내산) 시래기국  함박스테이크*소스  두부구이  오이무침  포기...
# 965  단호박영양밥 (쌀:국내산) 연두부탕  오징어숙회무침 (오징어:원양산) 고기전 (돼지...
#
#                                                   석식메뉴
# 964  유부초밥 (쌀:국내산) 쌀국수 (양지:호주산) 떡볶이  군만두  귤/음료  포기김치...
# 965  쌀밥/잡곡밥 (쌀:국내산) 시금치국  돈육고추장볶음  잡채  파채*소스/쌈무  포기...
# (241, 10)

# %%
y_test = y_test.reset_index(drop = True)
y_test.head()
# Out:
#       중식계    석식계
# 0   820.0  272.0
# 1   633.0  350.0
# 2   761.0  457.0
# 3   696.0  344.0
# 4  1075.0  439.0

# %% [markdown]
# 편한 전처리를 위해 ``` df``` 로 통합

# %%
df = pd.concat([train, test])

# %% [markdown]
# ## 데이터 전처리 및 EDA

# %%
def draw_missing_values_table(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = total / len(df) * 100
    dtypes = df.dtypes
    df_missing = pd.concat([total, percent, dtypes], axis=1, keys=['Count', 'Percent', 'Type'])
    return df_missing

# %% [markdown]
# test의 target label들(```중식계```, ```석식계```)를 제외한 나머지 컬럼에는 Null 값이 존재하지 않음

# %%
draw_missing_values_table(df)
# Out:
#                 Count  Percent     Type
# 석식계               241     20.0  float64
# 중식계               241     20.0  float64
# 석식메뉴                0      0.0   object
# 중식메뉴                0      0.0   object
# 조식메뉴                0      0.0   object
# 현본사소속재택근무자수         0      0.0  float64
# 본사시간외근무명령서승인건수      0      0.0    int64
# 본사출장자수              0      0.0    int64
# 본사휴가자수              0      0.0    int64
# 본사정원수               0      0.0    int64
# 요일                  0      0.0   object
# 일자                  0      0.0   object

# %%
df.head(2)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0

# %%
df.tail(2)
# Out:
#               일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 1203  2021-01-25  월   2983     107     153             616        327.0
# 1204  2021-01-26  화   2983      69     183             551        362.0
#
#                                                    조식메뉴  \
# 1203  모닝롤/호박고구마오븐구이 우유/주스 계란후라이/찐계란 누룽지탕/흑미밥 감자양파국 분...
# 1204  모닝롤/야채샌드 우유/주스 계란후라이/찐계란 참치죽/흑미밥 홍합탕 애호박새우젓볶음 ...
#
#                                                    중식메뉴  \
# 1203  쌀밥/흑미밥/찰현미밥 전주식콩나물해장국 돈육간장불고기 깐풍연근 연두부*달래양념장 봄...
# 1204  쌀밥/귀리밥/찰현미밥 들깨미역국 교촌간장치킨 옥수수콘치즈구이 가지고추장무침 포기김치...
#
#                                             석식메뉴  중식계  석식계
# 1203     흑미밥 열무된장국 장어강정*데리야끼소스 깻잎쌈*생강채 오이선 포기김치   NaN  NaN
# 1204  (New)할라피뇨멸치주먹밥 잔치국수 수제고기육전 쑥갓나물 양파초절임 깍두기   NaN  NaN

# %%
display(df.describe())
display(df.describe(include = "object"))
# Out:
#              본사정원수       본사휴가자수       본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# count  1205.000000  1205.000000  1205.000000     1205.000000  1205.000000
# mean   2807.815768   157.913693   241.142739      274.117012    43.506224
# std     171.264404   144.190572    43.532298      246.239651   109.937400
# min    2601.000000    23.000000    41.000000        0.000000     0.000000
# 25%    2645.000000    71.000000   217.000000        4.000000     0.000000
# 50%    2760.000000   105.000000   245.000000      299.000000     0.000000
# 75%    2962.000000   185.000000   272.000000      452.000000     0.000000
# max    3305.000000  1224.000000   378.000000     1044.000000   533.000000
#
#                중식계        석식계
# count   964.000000  964.00000
# mean    889.719917  469.84751
# std     206.212722  137.23013
# min     296.000000    0.00000
# 25%     760.000000  423.00000
# 50%     879.000000  492.50000
# 75%    1022.250000  549.00000
# max    1459.000000  905.00000
#                 일자    요일                                               조식메뉴  \
# count         1205  1205                                               1205
# unique        1205     5                                               1204
# top     2018-09-13     목  모닝롤/프렌치토스트  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 무채국  김...
# freq             1   244                                                  2
#
#                                                      중식메뉴           석식메뉴
# count                                                1205           1205
# unique                                               1198           1168
# top     쌀밥/잡곡밥 (쌀:국내산) 매운소고기국  유린기  코다리조림  치커리사과무침  포기...      *
# freq                                                    2             19

# %%
_=df.hist(bins = 100, figsize = (10, 10))
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
_= sns.pairplot(df)

# %%
def corr_with_target(df, target_col = None, size = (12, 8), absolute = False, rtn = False):
    df_corr = df.corr()  
    if absolute:
        df_corr = abs(df_corr)
    
    if target_col == None:
        target_col = df_corr.columns.tolist()
    df_to_plot = df_corr[target_col].drop(index=target_col).sort_values(target_col, ascending = [False] * len(target_col)).T
    plt.figure(figsize = size)
    sns.heatmap(df_to_plot, annot = True, fmt = ".2f", vmin = -1, vmax = 1, cmap = "RdBu_r")
    
    if rtn:
        return df_to_plot.T

# %% [markdown]
# ```중식계```, ```석식계```와 다른 수치형 변수와의 상관관계

# %%
corr_with_target(df, target_col = ["중식계", "석식계"], size = (10, 5), absolute = False)

# %% [markdown]
# ```일자```로부터 여러 날짜형 변수 추출

# %%
def extract_datetime(df, col_name):
    if col_name.encode().isalpha():
        df["year"] = pd.to_datetime(df[col_name]).dt.year
        df["quarter"] = pd.to_datetime(df[col_name]).dt.quarter
        df["month"] = pd.to_datetime(df[col_name]).dt.month
        df["day"] = pd.to_datetime(df[col_name]).dt.day
    else:
        df["연도"] = pd.to_datetime(df[col_name]).dt.year
        df["분기"] = pd.to_datetime(df[col_name]).dt.quarter
        df["월"] = pd.to_datetime(df[col_name]).dt.month
        df["일"] = pd.to_datetime(df[col_name]).dt.day
    return df

# %%
df = extract_datetime(df, "일자")
df["연도월"] = pd.to_datetime(df["일자"]).dt.strftime("%Y-%m")
df["연도분기"] = df["연도"].astype('string').str.cat(df["분기"].astype('string'), '-')
df.head(2)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴     중식계    석식계    연도  분기  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0  2016   1
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0  2016   1
#
#    월  일      연도월    연도분기
# 0  2  1  2016-02  2016-1
# 1  2  2  2016-02  2016-1

# %% [markdown]
# ### 메뉴 전처리

# %%
df["조식메뉴"].nunique(), df["중식메뉴"].nunique(), df["석식메뉴"].nunique() ## 일자별로 겹치는 메뉴가 있기는 하지만 거의 다 다름
# Out:
# (1204, 1198, 1168)

# %%
df["조식메뉴"].head()
# Out:
# 0    모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1    모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2    모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3    모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4    모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
# Name: 조식메뉴, dtype: object

# %%
df["조식메뉴"][0]
# Out:
# '모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐어채무침  포기김치 (배추,고추가루:국내산) '

# %%
def menu_tolist(string):
    menus = string.split()
    result = []
    for menu in menus:
        if menu[0] != "(" and menu[-1] != ")":
            if "쌀밥" in menu or "흑미밥" in menu or "추가밥" in menu:
                result.append("밥")
            elif "*" in menu:
                result.append(menu.split("*")[0])
            else:
                result.append(menu)

    return result

def make_main_menu(arr):
    main = []
    soup = []
    for menus in arr:
        print(menus)
        if (not menus) or (not menus[0]) or ("자기" in menus[0]) or ("가정의" in menus[0]):
            main.append("없음")
            soup.append("없음")
        else:
            soup.append(menus[1])
            if menus[0] == "밥":
                main.append(menus[2])
            else:
                main.append(menus[0])
        
    return main, soup

main, soup = make_main_menu(df["중식메뉴"].apply(menu_tolist))
df["중식메인"] = main
df["중식국"] = soup
main, soup = make_main_menu(df["석식메뉴"].apply(menu_tolist))
df["석식메인"] = main
df["석식국"] = soup
# Out:
# ['밥', '오징어찌개', '쇠불고기', '계란찜', '청포묵무침', '요구르트', '포기김치']
# ['밥', '김치찌개', '가자미튀김', '모둠소세지구이', '마늘쫑무침', '요구르트', '배추겉절이']
# ['카레덮밥', '팽이장국', '치킨핑거', '쫄면야채무침', '견과류조림', '요구르트', '포기김치']
# ['밥', '쇠고기무국', '주꾸미볶음', '부추전', '시금치나물', '요구르트', '포기김치']
# ['밥', '떡국', '돈육씨앗강정', '우엉잡채', '청경채무침', '요구르트', '포기김치']
# ['밥', '시래기국', '훈제오리구이', '도토리묵무침', '쌈무/양파절임', '요구르트', '포기김치']
# ['밥', '꽃게탕', '돈육굴소스볶음', '옥수수전', '유채나물', '요구르트', '포기김치']
# ['밥', '시금치국', '닭감자조림', '연두부', '콩나물무침', '요구르트', '포기김치']
# ['밥', '쇠고기무국', '탕수어', '오징어숙회무침', '취나물', '요구르트', '포기김치']
# ['밥', '냉이된장국', '쇠고기장조림', '통도라지구이', '치커리무침', '요구르트', '포기김치']
# ['낙지비빔밥', '유부장국', '고구마치즈구이', '해초무침', '요구르트', '요구르트', '포기김치']
# ['밥', '대구찌개', '마늘간장치킨', '새송이버섯볶음', '돌나물무침/치킨무', '요구르트', '포기김치']
# ['밥', '쇠고기느타리국', '갈치구이', '호박꼬지&고사리&무나물', '파래김', '부럼/요구르트', '포기김치']
# ['밥', '콩나물국', '돈육간장볶음', '버섯잡채', '꽃상추무침', '요구르트', '포기김치']
# ['비빔밥', '팽이장국', '소세지피망볶음', '맛탕', '귤', '요구르트', '포기김치']
# ['밥', '북어계란국', '닭갈비', '새싹두부구이', '곰피초장', '요구르트', '포기김치']
# ['밥', '수제비국', '오징어볶음', '계란찜', '도라지초무침', '요구르트', '포기김치']
# ['밥', '얼갈이된장국', '제육볶음', '늙은호박전', '치커리생채', '요구르트', '포기김치']
# ['밥', '쇠고기미역국', '주꾸미볶음', '맛살계란말이', '아삭고추무침', '포기김치']
# ['밥', '근대된장국', '탕수육', '새송이버섯조림', '무생채', '요구르트', '포기김치']
# ['밥', '부대찌개', '가자미튀김', '메추리알조림', '열무된장나물', '깍두기']
# ['밥', '콩나물국', '닭갈비', '모둠묵', '톳두부무침', '포기김치']
# ['밥', '차돌박이찌개', '고등어김치말이', '소세지구이', '풋마늘초무침', '깍두기']
# ['밥', '북어국', '돈육장조림', '홍어무침', '시금치나물', '포기김치']
# ['밥', '고추장찌개', '닭데리야끼조림', '해물파전', '취나물', '포기김치']
# ['밥', '배추된장국', '수제돈가스', '탕평채', '쫄면무침', '포기김치']
# ['밥', '어묵국', '돈육고추장볶음', '모둠양채쌈', '콩나물파채무침', '포기김치']
# ['밥', '쑥국', '소불고기', '골뱅이무침', '마늘쫑볶음', '포기김치']
# ['곤드레밥', '콩나물김치국', '미니채소떡갈비', '두부계란부침', '무나물', '포기김치']
# ['밥', '사골우거지국', '탕수어', '파래김', '깻순나물', '깍두기']
# ['밥', '시금치국', '훈제오리구이', '연근땅콩조림', '쌈무/부추생채', '포기김치']
# ['밥', '꽃게탕', '버섯불고기', '계란말이', '도토리묵무침', '포기김치']
# ['밥', '쇠고기샤브국', '코다리강정', '두부&김치볶음', '유채나물', '깍두기']
# ['콩나물밥', '맑은국', '치킨텐더', '땅콩조림', '실곤약초무침', '포기김치']
# ['밥', '북어계란국', '쇠고기장조림', '오징어초무침', '시래기나물', '포기김치']
# ['밥', '닭개장', '자반고등어구이', '비엔나볶음', '열무나물', '배추겉절이']
# ['밥', '얼갈이된장국', '닭갈비', '해파리냉채', '취나물', '포기김치']
# ['밥', '옹심이만두국', '주꾸미볶음', '새송이버섯전', '치커리유자청생채', '포기김치']
# ['봄새싹비빔밥', '쪽파국', '오징어튀김', '알감자버터구이', '오렌지', '포기김치']
# ['밥', '매운콩나물국', '돈육굴소스볶음', '동태전', '봄동나물', '포기김치']
# ['밥', '버섯들깨탕', '갈치조림', '우엉잡채', '아삭고추무침', '포기김치']
# ['밥', '순두부찌개', '쇠불고기', '브로컬리맛살볶음', '풋마늘초무침', '포기김치']
# ['밥', '북어국', '오징어볶음', '모둠소시지구이', '시금치나물', '포기김치']
# ['밥', '올갱이아욱국', '제육볶음', '두부조림', '모둠쌈', '포기김치']
# ['밥', '어묵국', '매운돼지갈비찜', '해물파전', '무생채', '포기김치']
# ['밥', '배추된장국', '순살양념치킨', '메추리알조림', '콩나물무침', '포기김치']
# ['밥', '시래기국', '훈제오리구이', '무쌈/양파절임', '풋마늘초무침', '포기김치']
# ['밥', '부대찌개', '쇠고기단호박조림', '열무나물', '시금치나물', '포기김치']
# ['밥', '수제비국', '돈육굴소스볶음', '양배추쌈', '무생채', '포기김치']
# ['밥', '냉이된장찌개', '닭데리야끼조림', '도라지초무침', '콩나물무침', '포기김치']
# ['밥', '배추된장국', '돈육강정', '콩나물잡채', '브로컬리두부무침', '포기김치']
# ['밥', '육개장', '꽁치한마리구이', '고기전', '해초무침', '포기김치']
# ['콩나물밥', '근대된장국', '매콤떡갈비조림', '청포묵무침', '부추생채', '포기김치']
# ['밥', '대구매운탕', '쇠고기볶음', '옥수수전', '청경채생채', '포기김치']
# ['밥', '북어국', '등갈비김치찜', '연근조림', '깻잎양념지', '열무김치']
# ['밥', '콩나물국', '돈간장불고기', '김치전', '버섯볶음', '포기김치']
# ['밥', '쇠고기무국', '주꾸미볶음', '치즈계란말이', '풋마늘대무침', '포기김치']
# ['나물비빔밥', '미소장국', '궁중떡찜', '알감자버터구이', '유기농식혜', '배추겉절이']
# ['밥', '미역국', '양념파닭', '동그랑땡부침', '콩자반/치킨무', '포기김치']
# ['밥', '돈육김치찌개', '미트볼조림', '고등어카레구이', '치커리사과무침', '깍두기']
# ['밥', '시금치국', '닭갈비', '맛살겨자채', '비름나물', '포기김치']
# ['곤드레밥', '무채국', '모둠장조림', '온두부', '실곤약초무침', '볶은김치']
# ['밥', '쇠고기샤브국', '오징어볶음', '동태전', '무생채', '포기김치']
# ['밥', '매운어묵국', '훈제오리구이', '무쌈/양파절임', '도토리묵무침', '포기김치']
# ['밥', '콩나물국', '버섯불고기', '오징어초무침', '시금치나물', '포기김치']
# ['단호박영양밥', '시래기된장국', '돈육칠리강정', '멸치크랜베리볶음', '가지나물', '포기김치']
# ['밥', '오징어국', '찜닭', '꽃맛살볶음', '통도라지구이', '포기김치']
# ['밥', '된장찌개', '매운돼지갈비찜', '해물파전', '치커리유자생채', '배추겉절이']
# ['밥', '감자고추장찌개', '돈육굴소스볶음', '계란찜', '꽃상추무침', '포기김치']
# ['밥', '들깨버섯탕', '고등어김치말이', '고기전', '비름나물', '깍두기']
# ['산채비빔밥', '미소장국', '치킨핑거', '연근땅콩조림', '요플레', '포기김치']
# ['밥', '열무된장국', '미니채소떡갈비', '골뱅이무침', '숙주나물', '포기김치']
# ['밥', '순두부찌개', '닭오븐구이', '새송이버섯전', '불미나리무침', '포기김치']
# ['밥', '북어콩나물국', '쇠고기불고기', '옥수수전', '오이무침', '포기김치']
# ['밥', '한방갈비탕', '꼬지삼색전', '오징어숙회무침', '치커리생채', '석박지']
# ['낙지볶음밥', '미역장국', '탕수어', '우엉조림', '매실주스', '포기김치']
# ['밥', '쇠고기해장국', '갈치구이', '비엔나감자볶음', '무생채', '포기김치']
# ['밥', '배추된장국', '닭양념조림', '동그랑땡전', '고구마순나물', '깍두기']
# ['밥', '콩나물김치국', '누룽지탕수육', '명태조림', '오이도라지생채', '포기김치']
# ['밥', '근대된장국', '닭갈비', '잡채', '깻잎양념지', '포기김치']
# ['열무비빔밥', '강된장찌개', '오징어튀김', '궁중떡볶이', '음료', '포기김치']
# ['밥', '오이미역냉국', '모둠장조림', '두부구이', '실곤약초무침', '포기김치']
# ['밥', '차돌박이찌개', '찜닭', '김치전', '머위대나물', '포기김치']
# ['밥', '북어계란국', '돈육굴소스볶음', '홍어채무침', '가지나물', '포기김치']
# ['밥', '참치김치찌개', '순살깐풍기', '맛살콩나물냉채', '브로컬리초장', '깍두기']
# ['밥', '매운콩나물국', '돼지갈비찜', '부추전', '비름나물', '포기김치']
# ['밥', '된장찌개', '오징어볶음', '모둠소시지구이', '치커리사과무침', '포기김치']
# ['밥', '북어콩나물국', '제육볶음', '참치야채전', '모둠쌈', '포기김치']
# ['밥', '배추된장국', '닭양념조림', '탕평채', '어묵볶음', '열무김치']
# ['카레덮밥', '맑은국', '떡갈비조림', '쫄면무침', '열무된장나물', '포기김치']
# ['밥', '부대찌개', '가자미양념찜', '고기전', '해초무침', '깍두기']
# ['밥', '꽃게탕', '돈육강정', '버섯잡채', '김구이', '포기김치']
# ['밥', '어묵국', '레몬탕수육', '명태엿장조림', '시금치나물', '포기김치']
# ['밥', '대구찌개', '간장치킨', '마늘쫑볶음', '오이무침/치킨무', '포기김치']
# ['밥', '시래기국', '돈삼겹보쌈', '새송이버섯전', '콩나물파채무침', '포기김치/상추쌈']
# ['밥', '쇠고기무국', '매콤낙지볶음', '메추리알조림', '숙주나물', '포기김치']
# ['밥', '도토리묵냉국', '목살데리야끼구이', '골뱅이무침&소면', '간장깻잎지', '포기김치']
# ['밥', '배추된장국', '훈제오리구이', '실곤약초무침', '쌈무/야채스틱', '포기김치']
# ['밥', '육개장', '고등어구이', '닭가슴살냉채', '마늘쫑무침', '포기김치']
# ['밥', '콩나물국', '간장돼지갈비찜', '계란말이', '상추겉절이', '포기김치']
# ['밥', '버섯들깨찌개', '닭오븐구이', '김치전', '치커리사과무침', '열무김치']
# ['밥', '수제비국', '유자청제육볶음', '두부새싹구이', '양배추쌈', '포기김치']
# ['밥', '감자고추장찌개', '버섯불고기', '맛살겨자초무침', '노각무침', '포기김치']
# ['밥', '쇠고기미역국', '꽁치김치말이찜', '모둠소세지구이', '비름나물', '배추겉절이']
# ['곤드레밥', '가쯔오장국', '닭강정', '해물파전', '통도라지구이', '포기김치']
# ['밥', '된장찌개', '갈치조림', '돈육잡채', '오이생채', '포기김치']
# ['밥', '우무묵냉국', '갈릭돈까스', '감자볶음', '영양부추', '알타리김치']
# ['밥', '호박잎찌개', '돈육굴소스볶음', '홍어채무침', '모듬쌈', '포기김치']
# ['밥', '건새우아욱국', '순살파닭', '꽃맛살볶음', '도라지나물', '포기김치']
# ['나물비빔밥', '오이냉국', '사천식탕수육', '감자만두', '수박', '포기김치']
# ['밥', '배추된장국', '매운주꾸미볶음', '동태전', '브로컬리두부무침', '알타리김치']
# ['밥', '북어계란국', '등갈비김치찜', '삼치구이', '가지나물', '열무김치']
# ['밥', '순두부찌개', '돈육떡강정', '새송이버섯전', '해초무침', '포기김치']
# ['밥', '시래기국', '목살데리야끼', '늙은호박전', '치커리들깨무침', '포기김치']
# ['밥', '사골우거지탕', '미트볼조림', '골뱅이무침', '청포묵무침', '포기김치']
# ['밥', '우묵콩국', '고추장불고기', '명태엿장조림', '깻잎지', '알타리김치']
# ['참치회덮밥', '미소장국', '고구마치즈구이', '춘권', '토마토/락교', '포기김치']
# ['밥', '쇠고기미역국', '불닭볶음', '해파리겨자채', '쌈무/참나물생채', '포기김치']
# ['밥', '청국장찌개', '미니채소떡갈비', '계란말이', '연근조림', '포기김치']
# ['밥', '시금치국', '동파삼겹수육', '감자채볶음', '오이도라지무침/수박', '포기김치']
# ['밥', '꽃게탕', '훈제오리냉채', '동그랑땡전', '콩자반', '배추겉절이']
# ['연복풍덮밥', '도토리묵냉국', '꽁치오븐구이', '마늘쫑무침', '양배추피클', '포기김치']
# ['밥', '부대찌개', '갈치구이', '닭살겨자냉채', '꽈리고추찜', '포기김치']
# ['열무보리비빔밥', '팽이장국', '꽃맛살볶음', '웨지감자오븐구이', '유기농식혜', '알타리김치']
# ['밥', '버섯들깨탕', '레몬탕수육', '메추리알조림', '콩나물무침', '포기김치']
# ['밥', '복숭아미역냉국', '닭데리야끼조림', '비엔나감자볶음', '시금치무침', '포기김치']
# ['밥', '된장찌개', '매콤돼지갈비찜', '연근/오징어튀김', '무생채', '열무김치']
# ['밥', '호박잎된장국', '유자청제육볶음', '오꼬노미계란말이', '도라지초무침', '포기김치']
# ['밥', '콩나물국', '미니함박조림', '오징어브로컬리숙회', '오이무침', '포기김치']
# ['밥', '사과오이냉국', '장어강정', '우엉잡채', '치커리생채', '포기김치']
# ['밥', '시래기국', '삼겹살오븐구이', '매운어묵볶음', '상추&마늘', '포기김치']
# ['불고기덮밥', '맑은국', '새우까스&탈탈소스', '고구마범벅', '노각무침', '포기김치']
# ['밥', '닭곰탕', '고등어조림', '비엔나피망볶음', '해초무침', '알타리김치']
# ['밥', '대구매운탕', '오징어볶음', '고기전', '청경채무침', '포기김치']
# ['밥', '열무된장국', '갈릭돈가스', '마늘쫑볶음', '실곤약초무침', '포기김치']
# ['단호박영양밥', '도토리묵냉국', '소고기숙주볶음', '땅콩조림', '쑥갓두부무침', '포기김치']
# ['밥', '꽃게탕', '고추잡채', '꽁치와사비구이', '오이무침', '포기김치']
# ['밥', '배추된장국', '칠리탕수육', '두부조림', '콩나물무침', '열무김치']
# ['밥', '해물된장찌개', '닭볶음', '연근조림', '치커리유자청무침', '포기김치']
# ['밥', '육개장', '동태무조림', '부추전', '올방개묵무침', '포기김치']
# ['밥', '떡국', '마늘치킨', '홍어채무침', '꽃맛살오리엔탈샐러드', '포기김치']
# ['밥', '순두부찌개', '소불고기', '골뱅이무침', '아삭고추무침', '포기김치']
# ['밥', '버섯매운탕', '갈치구이', '모듬소시지볶음', '호박잎쌈', '포기김치']
# ['낙지비빔밥', '가쯔오장국', '계란말이', '과일샐러드', '단무지무침', '열무김치']
# ['밥', '오징어국', '목살데리야끼', '버섯잡채', '브로컬리초장', '포기김치']
# ['밥', '시래기된장국', '닭찜', '해물파전', '청경채무침', '포기김치']
# ['밥', '쇠고기샤브국', '오징어볶음', '옥수수전', '연두부', '포기김치']
# ['밥', '부대찌개', '가자미카레튀김', '모둠버섯볶음', '참나물땅콩무침', '파김치']
# ['곤드레밥', '두부맑은국', '돈육떡강정', '계란찜', '오이무침', '포기김치']
# ['밥', '된장찌개', '오리고추장볶음', '콩나물잡채', '부추생채', '알타리김치']
# ['밥', '황태맑은국', '유린기', '도토리묵무침', '숙주나물', '포기김치']
# ['밥', '시래기국', '닭볶음', '동그랑땡', '상추겉절이', '깍두기']
# ['밥', '토란국', '매운돼지갈비찜', '어묵볶음', '쑥갓두부무침', '포기김치']
# ['밥', '어묵국', '오리훈제고추장볶음', '계란말이', '애호박나물', '포기김치']
# ['밥', '얼갈이된장국', '레몬탕수육', '감자채볶음', '참나물생채', '포기김치']
# ['열무비빔밥', '팽이장국', '너비아니구이', '땅콩조림', '핫도그/음료', '깍두기']
# ['밥', '쇠고기무국', '임연수찜', '햄피망볶음', '단배추나물', '포기김치']
# ['밥', '오징어국', '소고기숙주볶음', '두부조림', '무생채', '포기김치']
# ['밥', '아욱된장국', '유자청돈육볶음', '우엉잡채', '양배추쌈&쌈장', '포기김치']
# ['밥', '느타리버섯국', '간장파닭', '쫄면무침', '열무된장나물', '포기김치']
# ['카레덮밥', '맑은국', '샐러드파스타', '새송이버섯조림', '오이무침', '포기김치']
# ['밥', '된장찌개', '돈육장조림', '호박부추전', '올방개묵무침', '포기김치']
# ['밥', '우거지해장국', '꽁치한마리구이', '가지볶음', '브로컬리초장', '알타리김치']
# ['밥', '배추된장국', '버섯불고기', '골뱅이소면무침', '마늘쫑건새우볶음', '포기김치']
# ['밥', '차돌박이찌개', '매운주꾸미볶음', '모둠소세지구이', '콩나물무침', '포기김치']
# ['밥', '미역국', '한방소갈비찜', '오징어숙회무침', '동태/새송이전', '배추겉절이']
# ['밥', '대구매운탕', '표고돈육탕수', '메추리알곤약조림', '부추생채', '포기김치']
# ['밥', '쇠고기샤브국', '오징어볶음', '맛살계란말이', '참나물무침', '포기김치']
# ['밥', '시금치된장국', '목살스테이크', '버섯잡채', '오이무침', '배추겉절이']
# ['산채비빔밥', '팽이버섯국', '생선커틀릿', '', '오복지무침', '오렌지주스', '포기김치']
# ['밥', '떡국', '마늘치킨', '모듬묵', '열무된장나물', '포기김치']
# ['밥', '건새우무국', '등갈비김치찜', '계란버섯장조림', '애호박나물', '포기김치']
# ['밥', '미역국', '소불고기', '모둠양채쌈', '매운어묵볶음', '포기김치']
# ['밥', '꽃게탕', '미트볼칠리조림', '부추전', '치커리유자청무침', '포기김치']
# ['밥', '참치김치찌개', '유린기', '셀프무쌈말이', '멸치크렌베리볶음', '포기김치']
# ['밥', '꽁치김치말이', '메밀버섯전', '쑥갓두부무침', '알타리김치']
# ['짜장밥', '계란국', '사천식탕수육', '풍기샐러드', '단무지', '포기김치']
# ['밥', '된장찌개', '제육볶음', '해물파전', '콩나물무침', '포기김치']
# ['밥', '육개장', '갈치구이', '고추잡채', '미역레몬초무침', '깍두기']
# ['곤드레밥', '배추된장국', '데리야끼파닭', '실곤약초무침', '땅콩조림', '포기김치']
# ['밥', '동태찌개', '돈육장조림', '두부계란전', '해초무침', '포기김치']
# ['밥', '버섯들깨탕', '고등어조림', '비엔나감자볶음', '통도라지구이', '알타리김치']
# ['밥', '근대된장국', '쇠고기숙주볶음', '새송이버섯전', '홍어채무침', '포기김치']
# ['밥', '알탕', '닭갈비', '생선까스', '시금치나물', '포기김치']
# ['콩나물밥', '가쯔오장국', '훈제오리/무쌈', '양파절임', '부추겉절이', '포기김치']
# ['밥', '쇠고기무국', '쭈꾸미볶음', '계란말이', '세발나물', '포기김치']
# ['밥', '사골우거지탕', '명태엿장조림', '모듬소세지구이', '오이무침', '석박지']
# ['밥', '오징어국', '유자청제육볶음', '날치알계란찜', '상추파채무침', '포기김치']
# ['밥', '차돌박이찌개', '순살양념치킨', '동그랑땡전', '깻잎지', '포기김치']
# ['단호박영양밥', '꽃게탕', '고추잡채', '연근조림', '무생채/귤', '포기김치']
# ['밥', '김치콩나물국', '쇠고기장조림', '닭살겨자채', '멸치아몬드볶음', '알타리김치']
# ['밥', '아욱된장국', '칠리탕수육', '동태전', '치커리무침', '포기김치']
# ['밥', '어묵국', '소고기버섯볶음', '오징어숙회무침', '부추호박전', '포기김치']
# ['밥', '김치국', '닭데리야끼조림', '햄감자채볶음', '브로컬리무침', '포기김치']
# ['버섯영양밥', '조랭이떡미역국', '유산슬', '임연수구이', '청경채무침', '포기김치']
# ['밥', '설렁탕', '해물김치전', '올방개묵무침', '풋고추', '깍두기']
# ['밥', '콩비지찌개', '순살깐풍기', '어묵볶음', '쌈다시마초장', '갓김치']
# ['밥', '시래기된장국', '누룽지탕수육', '계란찜', '도라지초무침', '포기김치']
# ['밥', '대구매운탕', '쇠고기숙주볶음', '새싹두부구이', '오이생채', '포기김치']
# ['밥', '순두부탕', '파닭', '갈치조림', '청포묵무침', '포기김치']
# ['밥', '수제비국', '짬뽕불고기', '우엉잡채', '참나물', '포기김치']
# ['카레덮밥', '맑은국', '통감자오븐구이', '샐러드파스타', '연근땅콩조림', '베추겉절이']
# ['밥', '쇠고기느타리국', '오징어볶음', '모둠소시지구이', '물파래무침', '포기김치']
# ['밥', '근대국', '제육볶음', '늙은호박전', '모둠쌈', '포기김치']
# ['나물비빔밥', '가쯔오장국', '치킨핑거', '감자샐러드', '오복지무침', '포기김치']
# ['밥', '콩나물국', '모둠장조림', '골뱅이무침', '톳두부무침', '알타리김치']
# ['밥', '떡국', '양념찜닭', '콩나물겨자채', '청경채무침', '포기김치']
# ['밥', '순두부찌개', '훈제오리구이', '참치야채전', '무쌈말이', '포기김치']
# ['밥', '홍합탕', '삼겹살오븐구이', '실곤약흑임자무침', '배추쌈/무말랭이', '포기김치']
# ['짜장밥', '유부장국', '해물누룽지탕', '개성감자만두', '쨔샤이무침/아이스슈', '포기김치']
# ['밥', '아욱국', '양념돼지갈비찜', '버섯메밀전', '상추초무침', '알타리김치']
# ['밥', '차돌박이된장찌개', '삼치무조림', '닭가슴살냉채', '마늘쫑무침', '포기김치']
# ['밥', '콩나물김치국', '돈육굴소스볶음', '매운어묵무침', '다시마', '깍두기']
# ['밥', '냉이된장찌개', '코다리강정', '돈육잡채', '오이도라지무침', '포기김치']
# ['소불고기덮밥', '가쯔오장국', '고구마튀김', '멕시칸샐러드', '청경채무침', '포기김치']
# ['밥', '콩비지찌개', '오리고추장볶음', '옥수수계란찜', '부추생채', '포기김치']
# ['밥', '쇠고기샤브국', '갈치구이', '비엔케찹볶음', '아삭고추무침', '포기김치']
# ['밥', '배추된장국', '짬뽕불고기', '감자채볶음', '하루나겉절이', '포기김치']
# ['밥', '콩나물국', '고추잡채', '꽁치김치말이', '올방개묵무침', '깍두기']
# ['밥', '된장찌개', '마늘간장치킨', '홍어채무침', '가지나물', '포기김치']
# ['밥', '꽃게탕', '쇠고기버섯볶음', '양배추쌈', '오이무침', '포기김치']
# ['밥', '얼갈이국', '떡갈비조림', '동태전', '치커리유자청무침', '포기김치']
# ['밥', '동태찌개', '돈육간장불고기', '두부새싹구이', '풋마늘대무침', '포기김치']
# ['밥', '열무된장국', '닭갈비', '우엉잡채', '포기김치']
# ['콩나물밥', '가쯔오장국', '미트볼케찹조림', '꽃맛살샐러드', '군고구마', '배추겉절이']
# ['밥', '시래기국', '오징어볶음', '소세지감자조림', '쑥갓두부무침', '포기김치']
# ['밥', '순두부찌개', '수제돈까스', '꽈리고추어묵볶음', '물미역초장', '포기김치']
# ['밥', '사골떡국', '쇠고기낙지볶음', '부추깻잎전', '통도라지구이', '포기김치']
# ['밥', '홍합탕', '매운동태찜', '언양식불고기', '콩나물파채절이', '포기김치']
# ['곤드레밥', '황태국', '동그랑땡전', '비빔메밀국수', '꽈리고추멸치볶음', '배추겉절이']
# ['밥', '육개장', '굴비구이', '두반장감자볶음', '청경채생채', '포기김치']
# ['밥', '된장찌개', '레몬탕수육', '주꾸미초무침', '어묵볶음', '포기김치']
# ['밥', '콩나물국', '동파육', '무쌈말이', '쫑상추무침', '포기김치']
# ['밥', '쇠고기미역국', '주꾸미떡볶음', '고기전', '두반장가지볶음', '포기김치']
# ['비빔밥', '팽이장국', '생선까스', '씨리얼과일샐러드', '오복지무침', '포기김치']
# ['밥', '어묵국', '매운닭찜', '모듬버섯구이', '봄동된장무침', '배추겉절이']
# ['밥', '짬뽕국', '미니함박조림', '잡채', '치커리유자생채', '포기김치']
# ['밥', '얼갈이된장국', '오징어볶음', '꽃맛살햄볶음', '참나물땅콩무침', '포기김치']
# ['밥', '순두부찌개', '쇠고기숙주볶음', '삼색묵무침', '시금치초생채', '포기김치']
# ['밥', '아욱국', '훈제오리구이', '옥수수전', '무쌈/부추무침', '배추겉절이']
# ['밥', '수제비국', '유자청돈육볶음', '두부새싹구이', '청경채무침', '포기김치']
# ['밥', '닭개장', '가자미카레튀김', '비엔나케찹볶음', '파래김', '포기김치']
# ['밥', '냉이콩나물국', '닭볶음', '새송이버섯전', '마늘쫑무침', '포기김치']
# ['밥', '알탕', '돈육간장불고기', '감자채볶음', '깻잎찜', '포기김치']
# ['카레덮밥', '맑은국', '유린기', '개성감자만두', '오이사과무침', '포기김치']
# ['밥', '배추된장국', '소갈비찜', '삼색꼬지전', '콩나물무침', '포기김치']
# ['밥', '미역국', '언양식불고기', '양잡피잡채', '진미채무침', '포기김치']
# ['밥', '시금치된장국', '고추장불고기', '닭살겨자채', '모듬쌈', '포기김치']
# ['밥', '굴김치두부국', '스위트칠리미트볼', '갈치구이', '치커리생채', '알타리김치']
# ['밥', '콩나물국', '소고기낙지볶음', '연두부찜', '무생채', '포기김치']
# ['밥', '냉이된장찌개', '닭갈비', '감자전', '단배추나물', '포기김치']
# ['밥', '대구매운탕', '유산슬', '땅콩멸치볶음', '실곤약무침', '포기김치']
# ['콩나물밥', '맑은국', '닭오븐구이', '춘권', '물미역무침', '포기김치']
# ['밥', '배추국', '수제돈까스', '명태조림', '치커리생채', '알타리김치']
# ['오곡밥', '소고기무국', '굴비구이', '홍어무침', '보름나물/김구이', '포기김치']
# ['밥', '쇠고기미역국', '제육볶음', '두부구이', '도라지오이생채', '포기김치']
# ['밥', '된장찌개', '주꾸미볶음', '돈육잡채', '숙주나물', '배추겉절이']
# ['밥', '들깨시래기국', '순살파닭', '해물김치전', '다시마쌈', '포기김치']
# ['밥', '홍합탕', '소불고기', '오징어초무침', '얼갈이나물', '포기김치']
# ['밥', '어묵국', '등갈비김치찜', '동태전', '부추무침', '깍두기']
# ['밥', '열무된장국', '동파육', '새송이버섯전', '치커리유자무침', '포기김치']
# ['밥', '버섯들깨탕', '낙지볶음', '야채계란찜', '취나물', '배추겉절이']
# ['나물비빔밥', '유부장국', '생선까스', '파스타샐러드', '마늘쫑볶음', '알타리김치']
# ['밥', '콩나물국', '돼지갈비찜', '메추리알조림', '브로컬리초장', '포기김치']
# ['밥', '수제비국', '깐풍기', '어묵볶음', '톳무침', '포기김치']
# ['밥', '봄동된장국', '훈제오리구이', '녹두김치전', '양파절임/오이부추무침', '포기김치']
# ['밥', '사골떡국', '언양식불고기', '콩나물동태찜', '돌나물무침', '배추겉절이']
# ['밥', '돈육김치찌개', '팝콘치킨', '고등어조림', '해초무침', '깍두기']
# ['카레덮밥', '맑은국', '미니채소떡갈비', '군만두', '무피클', '포기김치']
# ['밥', '어묵국', '순살닭갈비', '동그랑땡전', '치커리사과무침', '포기김치']
# ['밥', '토란탕', '돈육칠리강정', '꽁치한마리구이', '봄동달래무침', '포기김치']
# ['곤드레밥', '미소국', '오징어볶음', '햄감자채볶음', '고추간장지', '포기김치']
# ['밥', '아욱국', '마늘치킨', '골뱅이무침', '숙주나물', '석박지']
# ['밥', '얼큰순두부찌개', '해물청경채볶음', '계란말이', '도라지오이생채', '포기김치']
# ['밥', '오징어국', '버섯불고기', '야채계란찜', '파래김', '포기김치']
# ['밥', '동태찌개', '미트볼케찹조림', '우엉잡채', '방풍나물', '포기김치']
# ['밥', '근대국', '양념찜닭', '옥수수전', '건새우마늘쫑볶음', '포기김치']
# ['밥', '옹심이만두국', '돈육굴소스볶음', '콩나물겨자채', '모듬쌈', '포기김치']
# ['밥', '고추장찌개', '치킨커틀렛', '연근땅콩조림', '시금치나물', '배추겉절이']
# ['밥', '아욱국', '콩나물불고기', '맛살전', '상추무침', '포기김치']
# ['밥', '냉이된장찌개', '쇠고기장조림', '굴비구이', '부추생채', '포기김치']
# ['밥', '돈육김치찌개', '유린기', '비엔나볶음', '세발나물', '깍두기']
# ['밥', '콩가루배추국', '돼지갈비찜', '물파래전', '통도라지구이', '포기김치']
# ['밥', '대구매운탕', '고추잡채', '올방개묵무침', '김구이', '포기김치']
# ['밥', '알탕', '소고기숙주볶음', '오꼬노미계란말이', '얼갈이나물', '포기김치']
# ['밥', '소고기미역국', '주꾸미볶음', '탕평채', '시금치나물', '포기김치']
# ['봄나물비빔밥', '팽이장국', '언양식불고기', '땅콩조림', '바나나', '포기김치']
# ['밥', '북어콩나물국', '사천식탕수육', '김치전', '쑥갓두부무침', '포기김치']
# ['밥', '생선커틀렛', '닭가슴살장조림', '콩나물무침', '포기김치']
# ['밥', '꽃게탕', '오이달래무침', '쌈무/양파절임', '포기김치']
# ['밥', '된장찌개', '쇠불고기', '동태전', '도토리묵무침', '배추겉절이']
# ['짜장밥', '맑은계란국', '유산슬', '부추만두', '단무지무침', '포기김치']
# ['밥', '근대국', '마늘치킨', '감자채전', '크래미숙주무침', '포기김치']
# ['밥', '육개장', '미니채소떡갈비', '버섯구이', '참나물생채', '포기김치']
# ['밥', '얼갈이국', '쇠고기낙지볶음', '날치알계란찜', '비름나물', '포기김치']
# ['밥', '김치찌개', '해물누룽지탕', '우엉잡채', '청경채무침', '열무김치']
# ['밥', '들깨미역국', '삼겹살오븐구이', '맛살콩나물냉채', '파채상추무침', '포기김치']
# ['밥', '황태국', '닭데리야끼조림', '매운어묵볶음', '시금치나물', '포기김치']
# ['밥', '쇠고기샤브국', '오징어볶음', '메추리알조림', '머위된장나물', '포기김치']
# ['밥', '된장찌개', '돈육굴소스볶음', '오징어숙회무침', '방풍나물', '포기김치']
# ['밥', '들깨시래기국', '쇠고기장조림', '시금치프리타타', '도라지생채', '얼갈이겉절이']
# ['곤드레밥', '맑은국', '탕수어', '쫄면무침', '요플레', '포기김치']
# ['밥', '아욱국', '등갈비김치찜', '참치야채전', '가지나물', '열무김치']
# ['밥', '콩나물김치국', '버섯불고기', '브로컬리맛살볶음', '부추생채', '포기김치']
# ['밥', '부대찌개', '언양식불고기', '계란장조림', '아삭고추된장무침', '포기김치']
# ['밥', '차돌박이찌개', '닭강정', '콩나물잡채', '도토리묵무침', '포기김치']
# ['비빔밥', '맑은국', '오징어튀김', '견과류조림', '하와이안샐러드', '깍두기']
# ['밥', '미역국', '매콤함박스테이크', '삼치구이', '영양부추생채', '열무김치']
# ['밥', '꽃게찌개', '탕수육', '곤약야채무침', '숙주나물', '배추겉절이']
# ['밥', '참치김치찌개', '훈제오리구이/쌈무', '올방개묵무침', '부추생채/양파절임', '열무김치']
# ['밥', '들깨미역국', '닭갈비', '생선까스', '무생채', '포기김치']
# ['밥', '고추장찌개', '쇠불고기', '홍어채무침', '머위대들깨볶음', '포기김치']
# ['밥', '된장찌개', '제육볶음', '잡채', '콩나물무침', '포기김치']
# ['밥', '콩가루배추국', '낙지볶음', '새송이버섯전', '비름나물', '깍두기']
# ['밥', '옹심이만두떡국', '유린기', '카레감자채볶음', '마늘쫑무침', '포기김치']
# ['밥', '콩비지찌개', '돈육꽈리고추볶음', '매운어묵볶음', '치커리유자청무침', '열무김치']
# ['밥', '쇠고기샤브국', '오징어볶음', '맛살계란찜', '양념깻잎지', '포기김치']
# ['밥', '열무된장국', '쇠고기장조림', '동태전', '미나리오이무침', '포기김치']
# ['밥', '부대찌개', '굴비구이', '고추잡채', '청경채무침', '깍두기']
# ['밥', '새우살미역국', '순살양념치킨', '콩나물겨자채', '참나물생채', '포기김치']
# ['밥', '시금치된장국', '제육볶음', '버섯구이', '양배추', '포기김치']
# ['밥', '소고기국', '간장찜닭', '부추전', '해초무침', '포기김치']
# ['콩나물밥', '김치국', '고등어구이', '감자프리타타', '고추지', '열무김치']
# ['밥', '들깨시래기국', '오리불고기', '두부조림', '상추겉절이', '오이소박이']
# ['밥', '콩나물국', '주꾸미떡볶음', '동그랑땡전', '부추생채', '포기김치']
# ['밥', '황태국', '소불고기', '계란찜', '청경채사과생채', '포기김치']
# ['밥', '얼갈이된장국', '동파삼겹수육', '맛살전', '아삭고추무침', '포기김치']
# ['열무보리비빔밥', '가쯔오장국', '탕수만두', '콥샐러드', '오이지무침', '포기김치']
# ['밥', '오이냉국', '등갈비김치찜', '어묵볶음', '참나물땅콩무침', '깍두기']
# ['밥', '돈육김치찌개', '삼치된장구이', '모듬소세지볶음', '도토리묵무침', '배추겉절이']
# ['밥', '근대국', '돈육굴소스볶음', '계란말이', '모둠쌈/씨앗쌈장', '포기김치']
# ['밥', '콩나물국', '훈제오리구이', '새송이버섯전', '쌈무/부추생채', '포기김치']
# ['밥', '얼갈이된장국', '미니채소떡갈비', '골뱅이무침', '숙주나물', '배추겉절이']
# ['밥', '호박잎된장찌개', '깐풍기', '어묵꽈리고추볶음', '실곤약초무침', '포기김치']
# ['밥', '연두부탕', '쇠고기숙주볶음', '홍어채무침', '고구마순나물', '포기김치']
# ['밥', '도토리묵냉국', '쭈꾸미볶음', '늙은호박전', '치커리사과생채', '깍두기']
# ['곤드레밥', '가쯔오장국', '치킨핑거', '파스타샐러드', '견과류조림', '포기김치']
# ['밥', '쇠고기샤브국', '갈치구이', '메추리알조림', '무생채', '배추겉절이']
# ['밥', '아욱된장국', '삼겹살구이', '감자채볶음', '쫑상추무침', '포기김치']
# ['밥', '들깨시래기국', '유자청제육볶음', '해물부추전', '오이도라지생채', '포기김치']
# ['밥', '오이지냉국', '고등어김치말이', '감자비엔나볶음', '연근조림', '열무김치']
# ['카레라이스', '유부주머니국', '언양식불고기', '떡볶이', '수박', '포기김치']
# ['밥', '쇠고기미역국', '해물누룽지탕', '비빔야채만두', '양념깻잎지', '포기김치']
# ['밥', '나가사끼짬뽕국', '닭갈비', '셀프무쌈말이', '콩나물무침', '포기김치']
# ['밥', '차돌박이찌개', '훈제오리고추장볶음', '곤약흑임자무침', '양배추쌈', '포기김치']
# ['밥', '북어콩나물국', '오징어볶음', '동그랑땡구이', '시금치나물', '포기김치']
# ['콩나물밥', '얼갈이된장국', '삼치구이', '잡채', '아삭고추무침', '깍두기']
# ['밥', '우무묵냉국', '갈릭돈까스', '두부양념조림', '부추생채', '포기김치']
# ['밥', '꼬지어묵탕', '매운닭찜', '감자채전', '미역줄기볶음', '열무김치']
# ['밥', '콩나물국', '짬뽕불고기', '계란찜', '청경채겉절이', '포기김치']
# ['밥', '배추된장국', '낙지볶음', '고기전', '미역레몬초무침', '포기김치']
# ['짜장덮밥', '계란국', '유산슬', '군만두', '단무지/사과', '열무김치']
# ['밥', '아욱된장국', '등갈비김치찜', '어묵볶음', '참나물', '알타리김치']
# ['밥', '오이냉국', '유린기', '도토리묵무침', '숙주나물', '포기김치']
# ['밥', '콩나물국', '버섯불고기', '해물겨자냉채', '우엉조림', '포기김치']
# ['밥', '어묵국', '주꾸미떡볶음', '두부계란구이', '브로컬리초장', '포기김치']
# ['<초복특식>', '삼계탕', '밥', '생야채&쌈장', '수박', '깍두기']
# ['밥', '근대국', '돼지갈비찜', '동태전', '치커리유자청무침', '포기김치']
# ['밥', '부대찌개', '갈치조림', '버섯잡채', '쑥갓두부무침', '알타리김치']
# ['밥', '무채국', '돈육고추장볶음', '간장두부조림', '모듬양채쌈', '포기김치']
# ['밥', '열무된장국', '간장찜닭', '통도라지구이', '치커리무침', '포기김치']
# ['김치제육덮밥', '맑은국', '양장피잡채', '오꼬노미야끼', '천도복숭아', '알타리김치']
# ['밥', '소고기매운무국', '오징어굴소스볶음', '모둠버섯구이', '오이무침', '포기김치']
# ['밥', '닭곰탕', '미트볼케찹조림', '메밀전', '영양부추생채', '포기김치']
# ['밥', '어묵탕', '콩나물불고기', '동그랑땡전', '얼갈이된장무침', '포기김치']
# ['밥', '된장찌개', '가자미카레튀김', '닭살냉채', '참나물무침', '배추겉절이']
# ['나물비빔밥', '미소장국', '파스타샐러드', '소세지오븐구이', '오렌지', '포기김치']
# ['밥', '콩나물냉국', '순살파닭', '오징어브로컬리', '멸치크렌베리볶음', '포기김치']
# ['밥', '쇠고기샤브국', '주꾸미떡볶음', '연두부', '해초무침', '포기김치']
# ['밥', '연두부탕', '쇠고기숙주볶음', '홍어채무침', '시래기조림', '포기김치']
# ['밥', '부대찌개', '해물누룽지탕', '우엉잡채', '머위대나물', '배추겉절이']
# ['밥', '꽃게탕', '미니채소떡갈비', '두부계란구이', '치커리사과생채', '포기김치']
# ['밥', '오이미역냉국', '닭오븐구이', '꽈리고추어묵조림', '무생채', '포기김치']
# ['밥', '콩나물국', '제육볶음', '메추리알조림', '호박잎/양배추쌈', '', '열무김치']
# ['밥', '어묵국', '쇠고기낙지볶음', '새송이버섯전', '참나물땅콩무침', '포기김치']
# ['밥', '미역국', '닭갈비', '시금치프리타타', '마늘쫑무침', '포기김치']
# ['밥', '도토리묵냉국', '수제돈까스', '두부양념조림', '단배추나물', '포기김치']
# ['밥', '돈육김치찌개', '갈치구이', '비엔나감자볶음', '셀프무쌈말이', '알타리김치']
# ['밥', '고추장찌개', '돈육보쌈', '쌈&야채스틱', '어묵볶음', '샐러드바:과일', '포기김치']
# ['밥', '된장찌개', '짬뽕불고기', '옥수수계란찜', '청경채생채', '포기김치']
# ['밥', '쇠고기무국', '오징어볶음', '모듬묵양념장', '오이무침', '포기김치']
# ['밥', '들깨시래기국', '매운닭찜', '임연수구이', '치커리무침', '포기김치']
# ['짜장밥', '맑은국', '해물까스', '부추만두', '단무지', '열무김치']
# ['밥', '조랭이떡미역국', '소고기불고기', '김치전', '콩나물무침', '포기김치']
# ['밥', '해물된장찌개', '표고버섯탕수육', '두부조림', '간장깻잎지', '배추겉절이']
# ['곤드레밥', '가쯔오장국', '가자미양념찜', '감자채볶음', '검정콩조림', '열무김치']
# ['밥', '쇠고기샤브국', '주꾸미굴소스볶음', '볼어묵볶음', '비름나물', '포기김치']
# ['밥', '알탕', '미트볼케찹조림', '계란말이', '마늘쫑무침', '포기김치']
# ['밥', '콩나물국', '돈육간장불고기', '매운어묵볶음', '쑥갓두부무침', '포기김치']
# ['밥', '배추된장국', '닭갈비', '동태전', '치커리사과생채', '포기김치']
# ['산채비빔밥', '미소장국', '언양식불고기', '과일샐러드', '아삭고추무침', '포기김치']
# ['밥', '육개장', '굴비구이', '탕수만두', '오이무침', '알타리김치']
# ['밥', '시래기국', '훈제오리구이', '두부구이', '쌈무/양파절임', '열무김치']
# ['밥', '북어국', '버섯불고기', '야채계란찜', '실곤약초무침', '포기김치']
# ['밥', '연두부탕', '등갈비김치찜', '도토리묵무침', '땅콩조림', '열무김치']
# ['밥', '꽃게탕', '마늘치킨', '양배추쌈', '고구마줄기볶음', '포기김치']
# ['밥', '쇠고기미역국', '오징어볶음', '고기전', '호박나물', '포기김치']
# ['밥', '열무된장국', '동파육', '셀프무쌈말이', '통도라지구이', '포기김치']
# ['밥', '시래기된장국', '유자청제육볶음', '오꼬노미야끼계란말이', '치커리무침', '포기김치']
# ['밥', '차돌박이찌개', '해물누룽지탕', '돈육잡채', '마늘쫑무침', '포기김치']
# ['카레라이스', '미소장국', '떡갈비조림', '모듬묵샐러드', '요플레/오복지', '포기김치']
# ['밥', '고사리육개장', '닭찜', '두부계란부침', '부추생채', '포기김치']
# ['밥', '참치김치찌개', '단호박장조림', '고등어구이', '참나물무침', '알타리김치']
# ['밥', '해물순두부찌개', '언양식불고기', '감자채전', '쫑상추무침', '포기김치']
# ['밥', '들깨버섯국', '소고기낙지볶음', '비엔나케찹조림', '취나물', '배추겉절이']
# ['콩나물밥', '가쯔오국', '감자프리타타', '메밀전병만두', '아삭고추무침', '포기김치']
# ['밥', '쇠고기샤브국', '꽁치구이', '김치제육볶음', '온두부', '열무김치']
# ['밥', '콩가루배추국', '순살양념치킨', '콩나물겨자채', '모듬묵', '포기김치']
# ['밥', '근대국', '짬뽕불고기', '실곤약흑임자무침', '도라지오이생채', '포기김치']
# ['밥', '시래기들깨탕', '닭갈비', '해물파전', '숙주나물', '포기김치']
# ['밥', '콩나물국', '삼겹살구이', '어묵볶음', '상추파무침', '포기김치']
# ['밥', '차돌박이찌개', '매운주꾸미볶음', '두부새싹구이', '브로컬리초장', '포기김치']
# ['밥', '미역국', '쇠불고기/잡채', '오징어숙회무침', '미니케익/식혜', '배추겉절이']
# ['밥', '아욱국', '훈제오리구이', '계란찜', '쌈무/부추생채', '포기김치']
# ['밥', '고추장찌개', '레몬탕수육', '궁중떡찜', '유채나물', '포기김치']
# ['밥', '해물된장찌개', '닭찜', '새송이버섯전', '얼갈이생채', '포기김치']
# ['밥', '쇠고기무국', '오징어볶음', '메추리알조림', '치커리유자청무침', '포기김치']
# ['밥', '차돌박이찌개', '제육볶음', '모둠쌈', '해파리겨자채', '포기김치']
# ['밥', '근대국', '고등어조림', '고추잡채', '참나물생채', '포기김치']
# ['밥', '민물새우찌개', '수제돈가스', '시금치프리타타', '오이무침', '포기김치']
# ['밥', '새알미역국', '유린기', '마파두부', '가지나물', '배추겉절이']
# ['밥', '쇠고기매운버섯국', '해물청경채볶음', '메밀부추전', '도라지초무침', '포기김치']
# ['밥', '콩나물국', '버섯불고기', '홍어채무침', '마늘쫑볶음', '포기김치']
# ['밥', '배추된장국', '쭈꾸미볶음', '두부계란부침', '미역줄기볶음', '포기김치']
# ['곤드레밥', '가쯔오장국', '갈치조림', '쇠고기잡채', '쑥갓두부무침', '알타리김치']
# ['밥', '육개장', '치킨핑거', '도토리묵무침', '물파래무침', '포기김치']
# ['밥', '시금치국', '돼지갈비찜', '어묵볶음', '무나물', '배추겉절이']
# ['밥', '들깨시래기국', '닭갈비', '연두부', '취나물', '포기김치']
# ['밥', '근대국', '돈삼겹보쌈', '옥수수전', '콩나물파채/상추쌈', '배추겉절이']
# ['카레덮밥', '맑은국', '개성감자만두', '파스타샐러드', '군고구마', '포기김치']
# ['밥', '사골떡국', '오징어볶음', '계란말이', '치커리사과생채', '포기김치']
# ['밥', '된장찌개', '누룽지탕수육', '실곤약초무침', '톳두부무침', '포기김치']
# ['밥', '콩가루배추국', '짬뽕불고기', '참치야채전', '호박나물', '포기김치']
# ['밥', '오징어국', '수제돈까스', '삼치구이', '봄동겉절이', '포기김치']
# ['콩나물밥', '미역장국', '언양식불고기', '도라지오이무침', '과일샐러드', '배추겉절이']
# ['밥', '해물된장찌개', '매운닭찜', '두부조림', '시금치나물', '포기김치']
# ['밥', '올갱이아욱국', '등갈비김치찜', '들깨버섯무침', '숙주나물', '깍두기']
# ['밥', '시금치국', '소고기불고기', '해물파전', '통도라지구이', '포기김치']
# ['밥', '새알미역국', '돼지갈비찜', '두부새싹구이', '세발나물', '알타리김치']
# ['곤드레밥', '청양된장찌개', '굴비구이', '궁중떡볶이', '무생채', '포기김치']
# ['밥', '북어계란국', '찜닭', '메밀전병만두', '가지무침', '포기김치']
# ['밥', '콩비지찌개', '미니채소떡갈비', '동태전', '양념깻잎지', '배추겉절이']
# ['밥', '차돌박이찌개', '오징어볶음', '계란말이', '치커리유자청무침', '알타리김치']
# ['밥', '어묵국', '순살파닭', '맛살겨자채', '물파래무침', '포기김치']
# ['단호박영양밥', '가쯔오장국', '돈육칠리강정', '모듬묵샐러드', '숙주나물', '깍두기']
# ['밥', '쇠고기무국', '갈치구이', '고추잡채', '오이무침', '포기김치']
# ['밥', '꽃게탕', '돈육굴소스볶음', '새송이버섯전', '물미역', '포기김치']
# ['밥', '아욱국', '버섯불고기', '골뱅이무침', '무나물', '포기김치']
# ['밥', '연두부탕', '사천식탕수육', '견과류조림', '참나물생채', '포기김치']
# ['나물비빔밥', '미소장국', '코다리조림', '과일샐러드', '군고구마', '깍두기']
# ['밥', '들깨시래기국', '제육볶음', '메추리알조림', '콩나물무침', '알타리김치']
# ['밥', '동태탕', '찜닭', '옥수수전', '취나물', '포기김치']
# ['밥', '들깨무채국', '돈육피망볶음', '모둠쌈', '해파리겨자채', '포기김치']
# ['밥', '소고기된장찌개', '낙지볶음', '계란찜', '오이생채', '배추겉절이']
# ['콩나물밥', '유부주머니국', '생선까스&탈탈소스', '두부양념조림', '단호박범벅', '포기김치']
# ['밥', '봄동된장국', '닭볶음탕', '부추전', '마늘쫑건새우볶음', '포기김치']
# ['밥', '부대찌개', '미트볼케찹조림', '사각어묵볶음', '김구이', '포기김치']
# ['밥', '해물된장찌개', '돈육굴소스볶음', '홍어채무침', '양념깻잎지', '포기김치']
# ['밥', '차돌박이찌개', '해물누룽지탕', '계란말이', '오이미역무침', '깍두기']
# ['카레라이스', '미소장국', '떡갈비조림', '모듬묵', '요플레/오복지', '포기김치']
# ['밥', '우거지해장국', '명태코다리조림', '비엔나케찹볶음', '시금치나물', '배추겉절이']
# ['밥', '들깨시래기국', '표고버섯탕수육', '두부오꼬노미야끼', '마늘쫑무침', '포기김치']
# ['밥', '오징어국', '버섯불고기', '실곤약초무침', '상추쑥갓생채', '포기김치']
# ['밥', '달래된장국', '주꾸미볶음', '시금치프리타타', '물미역', '포기김치']
# ['밥', '민물새우찌개', '동파육', '새송이버섯전', '파채콩나물무침', '배추겉절이']
# ['밥', '순두부찌개', '훈제오리구이', '어묵볶음', '쌈무/부추생채', '포기김치']
# ['밥', '콩나물국', '간장마늘치킨', '오징어초무침', '무나물', '포기김치']
# ['밥', '꽃게탕', '언양식불고기', '날치알계란찜', '호박나물', '포기김치']
# ['밥', '쇠고기미역국', '오징어볶음', '동그랑땡전', '무쌈말이', '포기김치']
# ['밥', '아욱된장국', '돼지갈비찜', '콩나물겨자채', '참나물무침', '포기김치']
# ['밥', '어묵국', '닭볶음탕', '연근땅콩조림', '파래김', '배추겉절이']
# ['밥', '사골떡국', '한방소갈비찜', '김치전', '오이무침/식혜', '포기김치']
# ['곤드레밥', '청량된장찌개', '굴비구이', '궁중떡볶이', '무생채', '포기김치']
# ['밥', '콩가루배추국', '제육볶음', '고구마그라탕', '모둠쌈', '깍두기']
# ['밥', '부대찌개', '깐풍기', '곤약어묵볶음', '매운콩나물무침', '깍두기']
# ['밥', '황태국', '소불고기', '계란찜', '청경채사과생채', '포기김치']
# ['밥', '근대국', '양파치킨', '비엔나케찹볶음', '유채나물', '포기김치']
# ['콩나물밥', '맑은국', '고추잡채', '해물까스', '참나물생채', '포기김치']
# ['밥', '봄동된장국', '오징어돈육볶음', '참치야채전', '호박나물', '배추겉절이']
# ['밥', '차돌박이찌개', '명태코다리강정', '모둠버섯볶음', '양념깻잎지', '포기김치']
# ['밥', '아욱국', '유자청제육볶음', '해물파전', '숙주나물', '포기김치']
# ['밥', '꽃게탕', '미니채소떡갈비', '쫄면무침', '참나물땅콩무침', '포기김치']
# ['나물비빔밥', '가쯔오장국', '치킨핑거', '마늘쫑볶음', '요플레', '포기김치']
# ['밥', '된장찌개', '쇠고기장조림', '해파리냉채', '통도라지구이', '알타리김치']
# ['밥', '육개장', '탕수어', '버섯잡채', '무생채', '포기김치']
# ['밥', '북어국', '쇠고기숙주볶음', '골뱅이무침', '세발나물무침', '포기김치']
# ['밥', '시금치된장국', '오징어볶음', '고기전', '봄동겉절이', '포기김치']
# ['짜장덮밥', '맑은국', '과일탕수육', '개성감자만두', '단무지', '배추겉절이']
# ['밥', '김치콩나물국', '돈육굴소스볶음', '황태양념구이', '모듬쌈', '포기김치']
# ['밥', '연두부탕', '순살파닭', '늙은호박전', '오이사과무침', '포기김치']
# ['밥', '봄동된장국', '가래떡돼지갈비찜', '콩나물겨자채', '참나물무침', '포기김치']
# ['밥', '어묵국', '닭볶음', '새송이버섯전', '가지나물', '포기김치']
# ['김치제육덮밥', '미소장국', '양장피잡채', '계란찜', '아삭고추무침/귤', '알타리김치']
# ['밥', '닭곰탕', '매콤미니함박', '삼치구이', '부추생채', '포기김치']
# ['밥', '차돌박이찌개', '표고버섯탕수육', '해물김치전', '숙주나물', '배추겉절이']
# ['밥', '순두부찌개', '돈육볶음', '홍어채무침', '시래기조림', '포기김치']
# ['밥', '해물된장찌개', '쇠고기장조림', '참치야채전', '콩나물무침', '알타리김치']
# ['콩나물밥', '유부주머니국', '언양식불고기', '치즈계란말이', '도라지오이무침', '포기김치']
# ['밥', '열무된장국', '동파삼겹수육', '연두부', '양념깻잎지', '배추겉절이']
# ['밥', '부대찌개', '해물청경채볶음', '메밀전', '도토리묵무침', '깍두기']
# ['밥', '차돌박이찌개', '닭갈비', '실곤약초무침', '양배추쌈', '포기김치']
# ['밥', '아욱된장국', '사천식탕수육', '모둠버섯볶음', '쑥갓두부무침', '포기김치']
# ['밥', '떡국', '버섯불고기', '오징어숙회무침', '취나물', '배추겉절이']
# ['밥', '들깨미역국', '훈제오리구이', '두부양념조림', '쌈무/부추생채', '포기김치']
# ['밥', '배추된장국', '짬뽕불고기', '늙은호박전', '청경채사과무침', '알타리김치']
# ['카레덮밥', '맑은국', '고구마치즈구이', '파스타샐러드', '오이무침', '포기김치']
# ['밥', '콩나물국', '마늘치킨', '모둠묵', '미역줄기볶음', '포기김치']
# ['밥', '시금치된장국', '등갈비김치찜', '맛살냉채', '쫑상추무침', '깍두기']
# ['밥', '황태국', '소고기숙주볶음', '새송이버섯전', '치커리무침', '포기김치']
# ['밥', '아욱된장국', '돼지갈비찜', '마늘쫑볶음', '곰피초장', '포기김치']
# ['곤드레밥', '어묵국', '치킨핑거', '도토리묵무침', '콩조림', '배추겉절이']
# ['밥', '차돌박이된장찌개', '조기구이', '오징어숙회무침', '보름나물/구이김', '부럼/포기김치']
# ['밥', '해물순두부찌개', '소고기장조림', '해파리냉채', '청경채생채', '알타리김치']
# ['밥', '근대된장국', '닭강정', '해물파전', '단배추나물/치킨무', '포기김치']
# ['콩나물밥', '가쯔오국', '삼치구이', '떡잡채', '얼갈이나물', '깍두기']
# ['밥', '홍합탕', '오리불고기', '탕평채', '간장깻잎지', '포기김치']
# ['밥', '쇠고기샤브국', '주꾸미볶음', '두부새싹구이', '참나물무침', '포기김치']
# ['밥', '배추된장국', '버섯불고기', '시금치프리타타', '부추생채', '포기김치']
# ['밥', '쇠고기무국', '미트볼케찹조림', '우엉잡채', '가지나물', '포기김치']
# ['밥', '시금치된장국', '탕수어', '두부', '시래기지짐', '깍두기']
# ['밥', '동태탕', '닭데리야끼조림', '어묵볶음', '숙주나물', '포기김치']
# ['밥', '얼갈이국', '오징어볶음', '동그랑땡전', '세발나물', '배추겉절이']
# ['밥', '어묵국', '돈육간장볶음', '골뱅이무침', '무나물', '포기김치']
# ['밥', '된장찌개', '해물누룽지탕', '고기전', '견과류조림', '포기김치']
# ['밥', '쇠고기미역국', '닭볶음탕', '도토리묵무침', '양배추쌈', '포기김치']
# ['밥', '우거지해장국', '코다리강정', '계란말이', '청경채나물', '깍두기']
# ['밥', '열무된장국', '수제돈까스', '메추리알곤약조림', '참나물생채', '포기김치']
# ['밥', '차돌박이찌개', '닭갈비', '새송이버섯조림', '치커리사과무침', '포기김치']
# ['밥', '콩나물국', '등갈비김치찜', '부추전', '흑임자연근샐러드', '알타리김치']
# ['단호박카레라이스', '유부장국', '유린기', '볼어묵볶음', '오복지', '포기김치']
# ['밥', '얼큰소고기국', '고추잡채', '계란찜', '숙주나물', '포기김치']
# ['밥', '참치김치찌개', '주꾸미볶음', '미니함박조림', '취나물무침', '깍두기']
# ['밥', '들깨버섯국', '소고기낙지볶음', '비엔나간장볶음', '아삭고추무침', '알타리김치']
# ['밥', '동태매운탕', '언양식불고기', '잡채', '쑥갓두부무침', '포기김치']
# ['곤드레밥', '가쯔오장국', '닭오븐구이', '오징어숙회무침', '시저샐러드', '포기김치']
# ['밥', '쑥된장국', '류산슬', '오꼬노미야끼계란말이', '오이도라지생채', '포기김치']
# ['밥', '수제비국', '양념치킨', '연두부', '진미채무침', '열무김치']
# ['밥', '콩나물국', '제육볶음', '해파리냉채', '모듬쌈', '포기김치']
# ['밥', '민물새우찌개', '소고기장조림', '홍어채무침', '참나물땅콩무침', '알타리김치']
# ['밥', '아욱국', '오징어볶음', '새싹두부구이', '해초무침', '배추겉절이']
# ['밥', '순두부찌개', '코다리양념조림', '모듬소시지구이', '청경채사과무침', '포기김치']
# ['밥', '근대국', '안동찜닭', '해물김치전', '부추생채', '열무김치']
# ['밥', '배추된장국', '짬뽕불고기', '버섯잡채', '청포묵무침', '포기김치']
# ['밥', '무채국', '훈제오리구이', '두부조림', '양파절임/쌈무', '배추겉절이']
# ['콩나물밥', '열무된장국', '치킨핑거', '궁중떡볶음', '오이미역무침', '포기김치']
# ['밥', '알탕', '돈육간장볶음', '실곤약초무침', '가지나물', '포기김치']
# ['밥', '돈육김치찌개', '가자미카레튀김', '야채계란찜', '쫑상추무침', '알타리김치']
# ['밥', '콩나물국', '류산슬', '계란말이', '오이도라지무침', '포기김치']
# ['밥', '쇠고기미역국', '깐풍기', '꽁치김치말이', '청경채새송이볶음', '포기김치']
# ['비빔밥', '유부장국', '오징어튀김', '떡밤초', '요플레', '포기김치']
# ['밥', '시래기국', '닭매운찜', '호박전', '쑥갓두부무침', '포기김치']
# ['밥', '순두부찌개', '삼겹살구이', '쫄면무침', '상추부추생채', '알타리김치']
# ['밥', '어묵국', '닭데리야끼조림', '꽃맛살볶음', '치커리무침', '포기김치']
# ['김치제육덮밥', '유부장국', '양장피잡채', '오꼬노미야끼', '오렌지', '알타리김치']
# ['밥', '도토리묵냉국', '수제돈까스', '어묵볶음', '오이미역무침', '열무김치']
# ['밥', '무청된장국', '콩나물제육볶음', '임연수구이', '취나물무침', '포기김치']
# ['밥', '배추된장국', '버섯불고기', '시금치프리타타', '무생채', '포기김치']
# ['밥', '돈육김치찌개', '탕수어', '우엉잡채', '도라지무침', '열무김치']
# ['밥', '근대국', '돈육굴소스볶음', '해파리겨자채', '양배추쌈', '포기김치']
# ['밥', '소고기무국', '오징어볶음', '두부계란부침', '미역줄기볶음', '배추겉절이']
# ['밥', '시금치된장국', '훈제오리구이', '실곤약무침', '무쌈/양파절임', '포기김치']
# ['밥', '얼갈이된장국', '등갈비김치찜', '새송이버섯전', '참나물생채', '열무김치']
# ['카레덮밥', '맑은국', '고구마치즈구이', '어묵꽈리고추볶음', '오이무침', '포기김치']
# ['밥', '콩나물국', '닭볶음탕', '탕평채', '영양부추무침', '포기김치']
# ['밥', '차돌박이된장찌개', '주꾸미볶음', '동그랑땡전', '양념깻잎지', '포기김치']
# ['밥', '시래기들깨탕', '짬뽕불고기', '멸치볶음', '상추파무침', '포기김치']
# ['곤드레밥', '얼갈이된장국', '마늘치킨', '오징어&브로컬리', '고추지무침', '포기김치']
# ['밥', '조랭이떡국', '돼지갈비찜', '두부구이', '치커리생채', '포기김치']
# ['밥', '사과오이냉국', '꽁치오븐구이', '떡갈비조림', '청경채무침', '포기김치']
# ['밥', '미역국', '제육볶음', '두부양념조림', '모듬쌈', '포기김치']
# ['밥', '김치찌개', '해물청경채볶음', '버섯잡채', '올방개묵무침', '알타리김치']
# ['콩나물밥', '유부장국', '수제돈가스', '파스타샐러드', '무생채', '포기김치']
# ['밥', '오징어국', '동파삼겹수육', '메밀부추전', '깻잎지', '포기김치']
# ['밥', '우거지해장국', '치킨핑거', '명태양념조림', '오이생채', '포기김치']
# ['밥', '콩나물국', '돈육간장볶음', '계란말이', '부추생채', '알타리김치']
# ['밥', '된장찌개', '닭갈비', '해파리겨자채', '취나물', '포기김치']
# ['밥', '순두부찌개', '고추잡채', '갈치구이', '도라지생채', '포기김치']
# ['밥', '대구매운탕', '완자전', '곤약메추리알조림', '마늘쫑볶음', '배추겉절이']
# ['밥', '배추된장국', '버섯불고기', '골뱅이무침', '콩나물무침', '포기김치']
# ['밥', '육개장', '고등어김치말이', '모듬소시지구이', '청경채무침', '알타리김치']
# ['밥', '근대국', '순살파닭', '카레감자채볶음', '호박나물', '포기김치']
# ['밥', '부대찌개', '오징어볶음', '연두부', '브로컬리맛살볶음', '배추겉절이']
# ['밥', '미역국', '훈제오리구이', '쫄면무침', '무쌈/양파절임', '포기김치']
# ['밥', '꽃게탕', '삼치데리야끼', '비엔나케찹볶음', '아삭고추무침', '포기김치']
# ['열무비빔밥', '팽이장국', '미니채소떡갈비', '땅콩조림', '방울토마토', '깍두기']
# ['밥', '오이냉국', '짬뽕불고기', '명란계란말이', '상추파무침', '포기김치']
# ['밥', '닭개장', '코다리강정', '잡채', '도토리묵무침', '포기김치']
# ['밥', '어묵국', '닭갈비', '시금치프리타타', '해초무침', '포기김치']
# ['밥', '돈육김치찌개', '류산슬', '생선커틀릿', '영양부추무침', '열무김치']
# ['카레덮밥', '가쯔오장국', '깐풍육', '구운채소', '', '오복지무침', '포기김치']
# ['밥', '들깨버섯국', '매운돼지갈비찜', '메추리알곤약조림', '도라지오이생채', '포기김치']
# ['밥', '육개장', '동태무조림', '메밀전병만두', '올방개묵무침', '포기김치']
# ['밥', '콩나물국', '유자청제육볶음', '계란말이', '미역줄기볶음', '포기김치']
# ['밥', '아욱국', '소고기장조림', '홍어채무침', '가지나물', '알타리김치']
# ['곤드레밥', '맑은국', '탕수어', '오이무침', '찐옥수수', '포기김치']
# ['밥', '근대국', '닭볶음탕', '해물파전', '도라지나물', '포기김치']
# ['밥', '도토리묵냉국', '동파삼겹수육', '매운어묵볶음', '쫑상추무침', '배추겉절이']
# ['밥', '고추장찌개', '돈육굴소스볶음', '브로컬리오징어숙회', '숙주나물', '포기김치']
# ['밥', '쇠고기매운국', '훈제오리구이', '우엉잡채', '양파절임/쌈무', '열무김치']
# ['나물비빔밥', '미소장국', '오징어튀김', '견과류조림', '과일샐러드', '포기김치']
# ['밥', '호박잎된장찌개', '깐풍기', '해파리겨자채', '도토리묵', '포기김치']
# ['밥', '어묵국', '등갈비김치찜', '연두부', '콩나물무침', '알타리김치']
# ['밥', '된장찌개', '소불고기', '동그랑땡전', '실곤약야채무침', '포기김치']
# ['삼계탕', '밥', '생야채', '참나물생채', '수박', '석박지']
# ['콩나물밥', '유부장국', '해물까스', '메추리알조림', '찐햇감자', '배추겉절이']
# ['밥', '해물순두부찌개', '안동찜닭', '부추전', '청경채무침', '포기김치']
# ['밥', '우무콩국', '유자청제육볶음', '통도라지구이', '호박잎', '포기김치']
# ['밥', '어묵국', '돈육굴소스볶음', '오징어야채무침', '간장깻잎지', '포기김치']
# ['밥', '우거지해장국', '삼치양념구이', '함박스테이크', '아삭고추무침', '포기김치']
# ['밥', '쇠고기샤브국', '유린기', '사각어묵볶음', '오이사과생채', '포기김치']
# ['밥', '오이지냉국', '매운돼지갈비찜', '콩나물냉채', '참나물땅콩무침', '포기김치']
# ['밥', '닭곰탕', '주꾸미떡볶음', '새송이버섯전', '치커리유자청무침', '포기김치']
# ['밥', '근대국', '닭갈비', '시금치프리타타', '도라지오이생채', '포기김치']
# ['밥', '콩나물국', '짬뽕불고기', '버섯잡채', '가지나물', '포기김치']
# ['카레덮밥', '가쯔오장국', '떡갈비조림', '감자만두', '오복지/과일', '포기김치']
# ['밥', '돈육김치찌개', '갈치양념조림', '옥수수전', '청경채사과무침', '열무김치']
# ['밥', '연두부탕', '닭오븐구이', '꽈리고추어묵조림', '브로컬리', '포기김치']
# ['밥', '콩나물김치국', '소불고기', '골뱅이무침', '호박나물', '알타리김치']
# ['밥', '얼갈이된장국', '오징어볶음', '닭살겨자냉채', '미역줄기볶음', '포기김치']
# ['열무보리비빔밥', '맑은국', '깐풍육', '꽃맛살샐러드', '찐옥수수', '포기김치']
# ['밥', '미역오이냉국', '돈육장조림', '온두부', '양념깻잎지', '볶음김치']
# ['밥', '된장찌개', '굴비구이', '미트볼케찹조림', '사과맛살초무침', '포기김치']
# ['밥', '들깨버섯국', '제육볶음', '계란찜', '참나물무침', '포기김치']
# ['밥', '차돌박이된장찌개', '해물누룽지탕', '쫄면야채무침', '해초무침', '열무김치']
# ['밥', '닭개장', '동태포전', '주꾸미굴소스볶음', '아삭고추무침', '포기김치']
# ['밥', '알탕', '쇠고기단호박조림', '두부오꼬노미야끼', '콩나물무침', '포기김치']
# ['밥', '시금치된장국', '훈제오리구이', '실곤약무침', '무쌈/양파절임', '포기김치']
# ['밥', '미역국', '소고기불고기', '양념두부조림', '도라지나물', '열무김치']
# ['비빔밥', '미소장국', '해물까스', '궁중떡볶이', '영양모듬견과', '포기김치']
# ['밥', '된장찌개', '꽁치레몬구이', '동그랑땡', '무생채', '포기김치']
# ['밥', '우무묵냉국', '마늘치킨', '계란말이', '치커리생채', '포기김치']
# ['밥', '배추된장국', '돈육간장불고기', '홍어채무침', '어묵볶음', '포기김치']
# ['밥', '쇠고기샤브국', '탕수어', '쫄면무침', '참나물땅콩무침', '포기김치']
# ['콩나물밥', '팽이장국', '치킨핑거', '메추리알조림', '과일샐러드', '배추겉절이']
# ['밥', '근대국', '모듬장조림', '마파두부', '숙주나물', '포기김치']
# ['밥', '조랭이떡국', '소고기낙지볶음', '두부새싹구이', '도라지생채', '포기김치']
# ['밥', '콩나물국', '버섯불고기', '브로컬리오징어숙회', '취나물', '포기김치']
# ['밥', '들깨시래기국', '동파삼겹수육', '녹두전', '야채스틱', '배추겉절이']
# ['김치제육덮밥', '맑은국', '샐러드파스타', '오징어튀김', '무생채', '열무김치']
# ['밥', '꽃게탕', '간장찜닭', '연두부', '마늘쫑무침', '포기김치']
# ['밥', '미역국', '매운주꾸미볶음', '새송이버섯전', '건파래무침', '포기김치']
# ['밥', '연두부국', '돈육고추장불고기', '감자채볶음', '양배추쌈', '포기김치']
# ['밥', '쇠고기미역국', '닭매운찜', '두부스테이크', '흑임자연근샐러드', '포기김치']
# ['소불고기덮밥', '가쯔오장국', '오징어튀김', '구운채소', '', '오복지무침', '포기김치']
# ['밥', '시래기국', '등갈비김치찜', '부추전', '콩나물무침', '포기김치']
# ['밥', '고추장찌개', '언양식불고기', '계란말이', '상추파무침', '포기김치']
# ['밥', '어묵국', '돈육굴소스볶음', '골뱅이무침', '무생채', '포기김치']
# ['밥', '닭개장', '류산슬', '김치전', '아삭고추무침', '포기김치']
# ['카레덮밥', '유부장국', '감자프리타타', '메밀전병만두', '쨔샤이무침/과일', '포기김치']
# ['밥', '꽃게탕', '소고기장조림', '명태조림', '파래김', '포기김치']
# ['밥', '아욱된장국', '돼지갈비찜/잡채', '쭈꾸미숙회무침', '송편/식혜', '배추겉절이']
# ['밥', '어묵탕', '돈육고추장불고기', '감자채볶음', '모듬쌈', '포기김치']
# ['곤드레밥', '맑은국', '돈육강정', '사과고구마그라탱', '오이초무침', '포기김치']
# ['밥', '들깨버섯국', '오징어볶음', '단호박계란찜', '청경채사과무침', '포기김치']
# ['밥', '설렁탕', '김치전', '오징어젓무침', '야채스틱/과일', '석박지']
# ['밥', '열무된장국', '버섯불고기', '맛살겨자채', '깻잎지', '포기김치']
# ['밥', '매운소고기무국', '조기구이', '우엉잡채', '참나물생채', '포기김치']
# ['콩나물밥', '유부장국', '생선가스', '가래떡구이', '땅콩조림', '포기김치']
# ['밥', '감자국', '김치제육볶음', '해물파전', '브로컬리들깨찜', '열무김치']
# ['밥', '오징어국', '닭갈비', '연두부', '호박나물', '포기김치']
# ['밥', '고추장찌개', '돈육간장불고기', '야채계란찜', '오이무침', '포기김치']
# ['밥', '콩비지찌개', '닭볶음탕', '메밀전병만두', '파래김', '포기김치']
# ['밥', '콩나물국', '등갈비김치찜', '어묵볶음', '톳두부무침', '깍두기']
# ['밥', '얼갈이국', '쇠고기낙지볶음', '시금치프리타타', '방풍나물', '포기김치']
# ['밥', '근대국', '오징어볶음', '두부새싹구이', '시금치나물', '배추겉절이']
# ['밥', '황태국', '소불고기', '홍어채무침', '콩나물무침', '포기김치']
# ['밥', '어묵국', '동파삼겹수육', '실곤약야채무침', '쫑상추무침', '배추겉절이']
# ['밥', '콩나물국', '수제돈가스', '닭살겨자채', '반달호박나물', '포기김치']
# ['밥', '시래기국', '마늘간장치킨', '새송이버섯전', '청경채생채', '포기김치']
# ['밥', '배추된장국', '훈제오리구이', '참치야채전', '무쌈/양파절임', '포기김치']
# ['밥', '쇠고기샤브국', '오징어볶음', '단호박계란찜', '도라지초무침', '포기김치']
# ['밥', '매운콩나물국', '닭데리야끼구이', '해파리냉채', '치커리생채', '배추겉절이']
# ['곤드레밥', '맑은국', '사천식탕수육', '탕평채', '오징어젓무침', '포기김치']
# ['밥', '미역국', '닭갈비', '동태포전', '무생채', '포기김치']
# ['밥', '육개장', '고등어구이', '비엔나케찹볶음', '연근조림', '포기김치']
# ['밥', '순두부찌개', '소고기불고기', '골뱅이무침', '아삭고추무침', '포기김치']
# ['밥', '청국장찌개', '돈육강정', '두부양념조림', '유채나물', '포기김치']
# ['콩나물밥', '팽이장국', '치킨핑거', '꽃맛살샐러드', '얼갈이겉절이', '포기김치']
# ['밥', '아욱국', '유자청제육볶음', '오징어숙회무침', '상추무침', '포기김치']
# ['밥', '알탕', '언양식불고기', '부추깻잎전', '도토리묵무침', '깍두기']
# ['밥', '꽃게탕', '돈육굴소스볶음', '매운어묵볶음', '콩나물무침', '포기김치']
# ['밥', '들깨시래기국', '주꾸미볶음', '메추리알조림', '통도라지구이', '포기김치']
# ['카레덮밥', '맑은국', '새우까스', '파스타샐러드', '오이무침', '포기김치']
# ['밥', '콩나물국', '닭볶음탕', '두부구이', '물파래무침', '포기김치']
# ['밥', '근대국', '버섯불고기', '쫄면무침', '취나물', '배추겉절이']
# ['밥', '얼갈이국', '닭갈비', '감자프리타타', '참나물생채', '포기김치']
# ['밥', '배추된장국', '짬뽕불고기', '늙은호박전', '연두부', '포기김치']
# ['나물비빔밥', '가쯔오장국', '오징어튀김', '과일샐러드', '군고구마', '포기김치']
# ['밥', '두부김치국', '레몬탕수육', '어묵꽈리고추볶음', '물미역', '알타리김치']
# ['밥', '매운버섯국', '해물누룽지탕', '계란말이', '얼갈이생채', '포기김치']
# ['밥', '미역국', '쇠고기낙지볶음', '계란찜', '세발나물', '포기김치']
# ['밥', '차돌박이찌개', '유린기', '모듬버섯볶음', '도라지초무침', '배추겉절이']
# ['단호박영양밥', '유부장국', '언양식불고기', '주꾸미초무침', '파래김', '포기김치']
# ['밥', '콩나물국', '오리불고기', '셀프무쌈말이', '쫑상추무침', '포기김치']
# ['밥', '떡만두국', '쇠고기모듬장조림', '동그랑땡전', '깻잎지', '포기김치']
# ['밥', '아욱국', '제육볶음', '감자그라탕', '콩나물파채무침', '포기김치']
# ['밥', '시금치국', '등갈비김치찜', '메밀전', '도토리묵무침', '알타리김치']
# ['콩나물밥', '가쯔오국', '가자미튀김', '고추잡채', '실곤약초무침', '배추겉절이']
# ['밥', '매운어묵국', '동파삼겹수육', '맛살전', '참나물겉절이', '포기김치']
# ['밥', '동태찌개', '치즈함박스테이크', '두부조림', '방풍나물', '포기김치']
# ['밥', '콩나물국', '짬뽕불고기', '메추리알조림', '건새우마늘쫑볶음', '포기김치']
# ['밥', '연두부탕', '닭볶음탕', '해물김치전', '물파래무침', '배추겉절이']
# ['곤드레밥', '팽이장국', '탕수어', '쫄면무침', '치커리유자청생채', '포기김치']
# ['밥', '근대국', '돼지갈비찜', '두부새싹구이', '호박나물', '알타리김치']
# ['밥', '닭개장', '갈치양념조림', '고기전', '비트무생채', '포기김치']
# ['밥', '열무된장국', '훈제오리구이', '매운어묵볶음', '쌈무/부추생채', '크리스마스케익', '포기김치']
# ['밥', '아욱국', '돈육굴소스볶음', '골뱅이무침', '얼갈이나물', '포기김치']
# ['밥', '순두부찌개', '오징어볶음', '계란말이', '참나물땅콩무침', '포기김치']
# ['밥', '고추장찌개', '버섯불고기', '해물동그랑땡', '유채나물', '포기김치']
# ['밥', '콩나물국', '돈육고추장불고기', '감자채볶음', '양배추쌈', '포기김치']
# ['밥', '떡국', '소갈비찜', '해물파전', '도라지오이무침/식혜', '포기김치']
# ['밥', '차돌박이찌개', '안동찜닭', '주꾸미초무침', '꽈리고추찜', '포기김치']
# ['밥', '두부김치국', '언양식불고기', '삼치구이', '물미역무침', '포기김치']
# ['밥', '시래기국', '쇠고기숙주볶음', '늙은호박전', '부추생채', '포기김치']
# ['밥', '콩나물국', '치즈함박스테이크', '고등어구이', '청경채생채', '포기김치']
# ['비빔밥', '맑은국', '치킨핑거', '하와이안샐러드', '검정콩조림', '포기김치']
# ['밥', '육개장', '탕수육', '감자프리타타', '깻잎지', '깍두기']
# ['밥', '꽃게탕', '고추잡채', '메밀전', '시금치나물', '포기김치']
# ['밥', '알탕', '돈육굴소스볶음', '감자채볶음', '마늘쫑무침', '포기김치']
# ['밥', '어묵국', '등갈비김치말이', '해파리냉채', '치커리유자청생채', '알타리김치']
# ['짜장덮밥', '맑은국', '유산슬', '군만두', '단무지/오렌지', '포기김치']
# ['밥', '봄동된장국', '쇠고기낙지볶음', '두부스테이크', '오이무침', '배추겉절이']
# ['밥', '콩나물김치국', '순살파닭', '실곤약초무침', '우엉조림', '포기김치']
# ['밥', '고추장찌개', '버섯불고기', '야채계란찜', '오이사과무침', '포기김치']
# ['밥', '배추된장국', '닭볶음탕', '새송이버섯전', '청경채생채', '알타리김치']
# ['콩나물밥', '맑은국', '생선까스', '파스타샐러드', '오복지무침', '포기김치']
# ['밥', '얼갈이국', '누룽지탕수육', '오징어초무침', '취나물', '포기김치']
# ['밥', '수제비국', '짬뽕불고기', '멸치호두볶음', '도라지나물', '배추겉절이']
# ['밥', '된장찌개', '김치제육볶음', '사과고구마그라탱', '브로컬리들깨찜', '포기김치']
# ['밥', '새알만두국', '양파치킨', '돈육잡채', '유채나물/치킨무', '포기김치']
# ['카레덮밥', '유부장국', '새우까스', '쫄면무침', '오이무침', '포기김치']
# ['밥', '청국장찌개', '갈치구이', '비엔나감자볶음', '콩나물겨자채무침', '포기김치']
# ['밥', '시금치국', '동파삼겹수육', '해물파전', '간장깻잎지', '포기김치']
# ['밥', '열무된장국', '훈제오리구이', '매운어묵볶음', '쌈무/부추생채', '포기김치']
# ['밥', '황태국', '제육볶음', '들깨버섯무침', '숙주나물', '알타리김치']
# ['밥', '어묵국', '소불고기', '계란말이', '실곤약초무침', '포기김치']
# ['밥', '순두부찌개', '돈육장조림', '옥수수전', '물미역', '포기김치']
# ['낙지비빔밥', '맑은국', '메추리알조림', '고구마튀김', '오복지무침', '포기김치']
# ['밥', '꽃게탕', '미니채소떡갈비', '카레감자채볶음', '양배추쌈', '포기김치']
# ['밥', '봄동된장국', '오징어볶음', '연두부', '미역줄기볶음', '포기김치']
# ['밥', '콩비지찌개', '치즈함박스테이크', '새송이버섯전', '유채나물', '포기김치']
# ['밥', '차돌박이찌개', '굴비구이', '오징어야채무침', '보름나물/구이김', '부럼/포기김치']
# ['곤드레밥', '맑은국', '치킨핑거', '김치찐만두', '무생채/요플레', '포기김치']
# ['밥', '아욱국', '돼지갈비찜', '시금치프리타타', '오이무침', '알타리김치']
# ['밥', '돈육김치찌개', '언양식불고기', '맛살냉채', '마늘쫑건새우볶음', '포기김치']
# ['밥', '고추장찌개', '버섯불고기', '두부양념조림', '참나물', '포기김치']
# ['밥', '쇠고기미역국', '미트볼칠리조림', '고등어구이', '숙주나물', '배추겉절이']
# ['비빔밥', '유부장국', '오징어튀김', '떡밤초', '음료', '포기김치']
# ['밥', '콩가루배추된장국', '돈삼겹보쌈', '매운어묵볶음', '무말랭이', '포기김치']
# ['밥', '해물된장찌개', '돈육간장불고기', '옥수수계란찜', '모듬쌈', '포기김치']
# ['밥', '육개장', '고추잡채', '삼치구이', '얼갈이나물', '포기김치']
# ['콩나물밥', '미역장국', '코다리강정', '닭가슴살냉채', '유채나물겉절이', '알타리김치']
# ['밥', '북어해장국', '소고기낙지볶음', '녹두전', '돌나물', '포기김치']
# ['밥', '차돌박이찌개', '해물누룽지탕', '비엔나컬리플라워조림', '열무나물무침', '배추겉절이']
# ['밥', '어묵국', '쇠고기숙주볶음', '감자프리타타', '건새우마늘쫑볶음', '포기김치']
# ['밥', '쑥국', '안동찜닭', '해물김치전', '풋마늘대무침', '포기김치']
# ['카레덮밥', '가쯔오장국', '고구마치즈구이', '쫄면무침', '무말랭이', '포기김치']
# ['밥', '우거지해장국', '갈치구이', '모듬소시지구이', '양념깻잎지', '열무김치']
# ['밥', '열무된장국', '등갈비김치찜', '메밀전병만두', '호박나물', '배추겉절이']
# ['밥', '콩나물국', '버섯불고기', '오징어숙회무침', '세발나물', '포기김치']
# ['밥', '아욱국', '동파육', '계란찜', '쫑상추무침', '배추겉절이']
# ['김치제육덮밥', '맑은국', '야채튀김', '시저샐러드', '오이무침', '알타리김치']
# ['밥', '미역국', '한방소갈비찜', '동태전/새송이전', '봄동겉절이', '식혜,오렌지,바나나', '깍두기']
# ['밥', '해물된장찌개', '돈육굴소스볶음', '달래두부무침', '양배추쌈', '포기김치']
# ['밥', '꽃게탕', '소고기장조림', '두부구이', '방풍나물', '포기김치']
# ['밥', '무채국', '제육볶음', '들깨버섯무침', '얼갈이나물', '포기김치']
# ['단호박영양밥', '가쯔오장국', '돈육칠리강정', '모듬묵샐러드', '숙주나물', '배추겉절이']
# ['밥', '어묵탕', '매운돼지갈비찜', '야채계란말이', '부추팽이겉절이', '열무김치']
# ['밥', '알탕', '미니함박조림', '셀프무쌈말이', '파래김', '포기김치']
# ['밥', '황태국', '소고기숙주볶음', '계란찜', '치커리무침', '포기김치']
# ['밥', '연두부탕', '오징어볶음', '궁중떡볶음', '참나물무침', '포기김치']
# ['곤드레밥', '들깨시래기국', '순대볶음', '쫄면', '온두부', '볶음김치']
# ['밥', '돈육김치찌개', '안동찜닭', '야채비빔만두', '아삭고추무침', '열무김치']
# ['밥', '조랭이떡미역국', '짬뽕불고기', '맛살전', '간장깻잎지', '배추겉절이']
# ['밥', '된장찌개', '유자청돈육볶음', '새송이버섯전', '모듬쌈', '포기김치']
# ['밥', '순두부찌개', '주꾸미볶음', '감자채볶음', '견과류조림', '열무김치']
# ['나물비빔밥', '가쯔오장국', '오징어튀김', '과일샐러드', '오복지', '포기김치']
# ['밥', '콩나물국', '수제돈까스', '파스타샐러드', '오이무침', '포기김치']
# ['밥', '아욱국', '닭오븐구이', '옥수수전', '치커리사과생채', '배추겉절이']
# ['밥', '매운어묵국', '버섯불고기', '시금치프리타타', '도라지오이생채', '포기김치']
# ['밥', '열무된장국', '닭볶음탕', '우엉잡채', '고구마순나물', '포기김치']
# ['밥', '떡국', '오징어볶음', '계란장조림', '양념깻잎지', '포기김치']
# ['밥', '매운버섯국', '미트볼케찹조림', '어묵볶음', '세발나물', '열무김치']
# ['짜장덮밥', '맑은국', '사천식탕수육', '군만두', '단무지', '포기김치']
# ['밥', '들깨시래기국', '유자청돈육볶음', '콩나물겨자채', '양배추쌈', '포기김치']
# ['밥', '된장찌개', '쇠고기장조림', '골뱅이무침', '취나물무침', '포기김치']
# ['카레라이스', '미소장국', '언양식불고기', '떡볶이', '방울토마토', '포기김치']
# ['밥', '두부김치국', '해물누룽지탕', '두부카프레제', '무나물', '열무김치']
# ['밥', '미역국', '돈육간장강정', '황태양념구이', '숙주나물', '포기김치']
# ['밥', '김치콩나물국', '버섯불고기', '계란찜', '부추생채', '포기김치']
# ['밥', '소고기샤브국', '오징어볶음', '모듬묵샐러드', '연근조림', '포기김치']
# ['밥', '해물된장찌개', '안동찜닭', '버섯볶음', '치커리생채', '포기김치']
# ['밥', '순두부찌개', '미니채소떡갈비', '사각어묵무침', '단배추나물', '배추겉절이']
# ['밥', '어묵국', '훈제오리구이', '두부조림', '양파절임/쌈무', '포기김치']
# ['콩나물밥', '가쯔오장국', '치킨핑거/요거트D', '메추리알조림', '청경채생채', '포기김치']
# ['밥', '근대국', '보쌈', '상추쌈/고추/마늘', '무말랭이무침', '배추겉절이']
# ['밥', '참치김치찌개', '소고기장조림', '실곤약초무침', '셀프무쌈말이', '깍두기']
# ['밥', '아욱국', '제육볶음', '해파리겨자채', '호박나물', '포기김치']
# ['밥', '차돌된장찌개', '해물청경채볶음', '고기전', '미역줄기볶음', '포기김치']
# ['산채비빔밥', '가쯔오장국', '치킨너겟', '콘샐러드', '연근땅콩조림', '포기김치']
# ['밥', '연두부탕', '돼지갈비찜', '계란말이', '취나물', '포기김치']
# ['밥', '버섯매운탕', '탕수어', '온두부', '치커리유자청무침', '볶음김치']
# ['밥', '된장찌개', '소고기숙주나물볶음', '코다리조림', '방풍나물', '포기김치']
# ['밥', '해물순두부찌개', '수원왕갈비통닭', '사각어묵볶음', '참나물생채', '열무김치']
# ['밥', '꽃게탕', '새송이떡갈비구이', '도토리묵야채무침', '연두부', '포기김치']
# ['밥', '소고기국', '가자미튀김', '돈육장조림', '시금치고추장무침', '포기김치']
# ['낙지비빔밥', '콩나물국', '부추전', '계란찜', '땅콩조림', '포기김치']
# ['밥', '북어국', '돈육콩나물불고기', '시금치프리타타', '쫑상추무침', '포기김치']
# ['밥', '오징어국', '안동찜닭', '감자채전', '오이소박이', '포기김치']
# ['밥', '배추된장국', '수제돈가스', '마파두부', '돈나물유자청무침', '포기김치']
# ['밥', '육개장', '고등어구이', '야채비빔만두', '파래김', '깍두기']
# ['봄나물비빔밥', '맑은국', '함박스테이크', '동태전', '마늘쫑무침', '포기김치']
# ['밥', '콩나물국', '짬뽕불고기', '메추리알조림', '모듬쌈', '포기김치']
# ['밥', '아욱국', '등갈비김치찜', '두부계란부침', '콩나물무침', '열무김치']
# ['곤드레밥', '맑은국', '코다리조림', '계란말이', '과일샐러드', '포기김치']
# ['밥', '고추장찌개', '언양식불고기', '버섯잡채', '오이무침', '포기김치']
# ['밥', '매운어묵국', '소불고기', '골뱅이무침', '숙주나물', '포기김치']
# ['밥', '부대찌개', '오징어볶음', '연두부', '땅콩조림', '열무김치']
# ['김치제육덮밥', '맑은국', '사과고구마그라탕', '맛살냉채', '오복지무침', '깍두기']
# ['밥', '옹심이만두국', '닭볶음탕', '신김치도토리묵', '치커리유자청생채', '포기김치']
# ['밥', '오이냉국', '사천식탕수육', '해물파전', '양념깻잎지', '포기김치']
# ['밥', '열무된장국', '돼지고기유자청볶음', '잡채', '취나물무침', '포기김치']
# ['밥', '북어해장국', '매운돼지갈비찜', '흑임자연근샐러드', '무생채', '포기김치']
# ['짜장덮밥', '맑은국', '깐풍기', '물만두', '단무지/쨔샤이무침', '포기김치']
# ['밥', '감자국', '주꾸미볶음', '시금치프리타타', '아삭고추무침', '포기김치']
# ['밥', '청국장찌개', '소고기장조림', '김치전', '사과오이초무침', '포기김치']
# ['밥', '어묵국', '소불고기', '옥수수계란찜', '가지나물', '포기김치']
# ['밥', '참치김치찌개', '돈육장조림', '맛살전', '해파리냉채', '열무김치']
# ['카레덮밥', '가쯔오장국', '고구마치즈구이', '쫄면무침', '무말랭이', '포기김치']
# ['밥', '소고기미역국', '양념치킨', '비엔나볶음', '파래김', '배추겉절이']
# ['콩나물밥', '팽이장국', '치킨핑거', '꽃맛살샐러드', '얼갈이겉절이', '포기김치']
# ['밥', '순두부찌개', '치즈함박스테이크', '매운어묵볶음', '청경채생채', '포기김치']
# ['밥', '사과오이냉국', '쇠고기낙지볶음', '우엉잡채', '쫑상추무침', '포기김치']
# ['마파두부덮밥', '맑은국', '치킨너겟', '파스타샐러드', '찐옥수수', '포기김치']
# ['밥', '열무된장국', '짬뽕불고기', '감자채볶음', '호박잎', '포기김치']
# ['밥', '김치두부국', '훈제오리구이', '동그랑땡전', '쌈무/양파절임', '부추겉절이', '열무김치']
# ['밥', '오징어국', '버섯불고기', '꽃맛살볶음', '치커리유자청생채', '포기김치']
# ['밥', '시래기국', '닭볶음탕', '어묵꽈리볶음', '도라지생채', '포기김치']
# ['열무보리비빔밥', '가쯔오장국', '깐풍육', '시저샐러드', '오복지무침', '포기김치']
# ['밥', '근대국', '삼겹보쌈', '해물김치전', '무말랭이', '배추겉절이']
# ['<초복특식>', '삼계탕', '밥', '생야채&쌈장', '수박', '수제석박지']
# ['밥', '차돌박이찌개', '돈육굴소스볶음', '주꾸미야채무침', '시금치나물', '포기김치']
# ['밥', '북어계란국', '닭갈비', '간장두부조림', '셀프무쌈말이', '열무김치']
# ['산채비빔밥', '미소장국', '야채튀김', '아삭고추무침', '요플레', '포기김치']
# ['밥', '돈육김치찌개', '미니채소떡갈비', '모듬묵양념장', '참나물생채', '배추겉절이']
# ['밥', '소고기무국', '갈치구이', '비엔나감자볶음', '무생채', '포기김치']
# ['밥', '매운어묵국', '소고기숙주볶음', '치킨샐러드', '양파짱아찌', '포기김치']
# ['밥', '시금치된장국', '등갈비김치찜', '파프리카잡채', '콩나물무침', '깍두기']
# ['카레라이스', '가쯔오국', '갈비통통만두', '쫄면야채무침', '호두견과류강정', '포기김치']
# ['밥', '매운소고기국', '유린기', '코다리조림', '치커리사과무침', '포기김치']
# ['밥', '우묵냉국', '고구마함박스테이크', '김치전', '오이맛살초무침', '포기김치']
# ['밥', '시금치국', '유자청제육볶음', '사과고구마그라탕', '오이무침', '포기김치']
# ['밥', '사과오이냉국', '장어강정', '햄감자채볶음', '콩나물무침', '포기김치']
# ['곤드레밥', '맑은국', '해물누룽지탕', '메밀전병만두', '오복지/찐햇감자', '포기김치']
# ['밥', '아욱국', '닭볶음탕', '오징어브로컬리숙회', '청경채생채', '배추겉절이']
# ['밥', '고추장찌개', '미트볼케찹조림', '계란말이', '꽈리고추찜', '포기김치']
# ['밥', '콩나물국', '닭갈비', '실곤약흑임자무침', '건새우마늘쫑볶음', '포기김치']
# ['밥', '도토리묵냉국', '짬뽕불고기', '계란찜', '양배추쌈', '포기김치']
# ['짜장덮밥', '맑은국', '고추잡채', '군만두', '단무지무침', '포기김치']
# ['밥', '아욱국', '돼지갈비찜', '어묵볶음', '치커리유자청무침', '배추겉절이']
# ['밥', '차돌된장찌개', '주꾸미볶음', '옥수수전', '양념깻잎지', '포기김치']
# ['밥', '된장찌개', '소고기숙주볶음', '모듬묵', '고추잎나물', '포기김치']
# ['밥', '꽃게탕', '언양식불고기', '감자프리타타', '깻잎찜', '포기김치']
# ['콩나물밥', '올챙이만두국', '유린기', '모히토과일샐러드', '쨔샤이무침', '포기김치']
# ['밥', '닭개장', '쇠고기장조림', '잡채', '비름나물된장무침', '포기김치']
# ['밥', '시래기국', '유자청제육볶음', '해물겨자냉채', '연두부', '포기김치']
# ['밥', '소고기미역국', '닭강정', '모듬소세지구이', '얼갈이겉절이', '포기김치']
# ['산채비빔밥', '미소장국', '오징어튀김', '아삭고추무침', '요플레', '포기김치']
# ['밥', '닭곰탕', '류산슬', '오꼬노미야끼계란말이', '오이도라지생채', '열무김치']
# ['밥', '돈육김치찌개', '미니채소떡갈비', '자반고등어구이', '숙주나물', '배추겉절이']
# ['밥', '꽃게탕', '함박스테이크', '사과고구마그라탕', '콩나물무침', '포기김치']
# ['밥', '고추장찌개', '버섯불고기', '동태전', '레몬미역초무침', '포기김치']
# ['카레덮밥', '맑은국', '치킨핑거', '쫄면야채무침', '오복지/과일', '포기김치']
# ['밥', '배추된장국', '훈제오리구이', '매운어묵볶음', '쌈무/양파절임', '부추겉절이', '포기김치']
# ['밥', '부대찌개', '굴비구이', '비엔나컬리플라워볶음', '김구이', '배추겉절이']
# ['밥', '들깨시락국', '돈육김치볶음', '궁중떡볶음', '쫑상추무침', '포기김치']
# ['밥', '차돌박이찌개', '소고기장조림', '갈치무조림', '참나물생채', '포기김치']
# ['단호박영양밥', '유부장국', '새송이너비아니구이', '양장피', '오이무침', '포기김치']
# ['밥', '토란국', '매운돼지갈비찜', '호박부추전', '도토리묵야채무침', '포기김치']
# ['밥', '된장찌개', '수제돈까스', '통도라지구이', '미역무침', '배추겉절이']
# ['밥', '김치콩나물국', '짬뽕불고기', '버섯잡채', '모듬쌈', '포기김치']
# ['밥', '맑은순두부국', '사천식탕수육', '감자프리타타', '청경채겉절이', '포기김치']
# ['나물비빔밥', '팽이장국', '생선까스', '갈비만두', '송편/식혜/과일', '포기김치']
# ['밥', '황태국', '훈제오리고추장볶음', '연두부', '쌈무/부추생채', '포기김치']
# ['밥', '꽃게된장찌개', '돈육굴소스볶음', '날치알계란찜', '꽃상추겉절이', '포기김치']
# ['밥', '소고기미역국', '탄두리치킨', '오징어숙회무침', '파스타샐러드', '/오렌지주스', '배추겉절이/과일']
# ['밥', '쇠고기샤브국', '주꾸미볶음', '카레감자채볶음', '호박나물', '포기김치']
# ['밥', '열무된장국', '대패삼겹', '사각어묵무침', '비름나물', '포기김치']
# ['밥', '근대국', '유자청제육볶음', '동그랑땡전', '얼갈이겉절이', '포기김치']
# ['밥', '얼갈이된장국', '버섯불고기', '골뱅이무침', '미역줄기볶음', '포기김치']
# ['곤드레밥', '맑은국', '돈육강정', '사과고구마그라탕', '오복지무침', '포기김치']
# ['밥', '콩나물김치국', '해물누룽지탕', '두부스테이크', '마늘쫑무침', '깍두기']
# ['밥', '어묵국', '언양식불고기', '계란말이', '청경채생채', '포기김치']
# ['밥', '콩가루배추국', '짬뽕불고기', '메추리알조림', '얼갈이겉절이', '포기김치']
# ['밥', '돈육김치찌개', '닭갈비', '우엉잡채', '부추겉절이', '깍두기']
# ['밥', '해물된장찌개', '소불고기', '두부양념조림', '미역레몬초무침', '포기김치']
# ['밥', '콩비지찌개', '돈육굴소스볶음', '해파리겨자채', '마늘쫑건새우볶음', '포기김치']
# ['밥', '동태탕', '마늘간장치킨', '새송이버섯전', '치커리사과무침', '포기김치']
# ['밥', '옹심이만두국', '굴비구이', '미트볼조림', '청경채무침', '포기김치']
# ['밥', '아욱국', '매운돼지갈비찜', '파스타샐러드', '건파래무침', '배추겉절이']
# ['밥', '북어해장국', '제육볶음', '감자채볶음', '야채스틱', '포기김치']
# ['밥', '콩나물국', '닭갈비', '어묵볶음', '부추생채', '포기김치']
# ['콩나물밥', '가쯔오국', '돈육강정', '모히토과일샐러드', '쨔샤이무침', '포기김치']
# ['밥', '알탕', '해물굴소스볶음', '쇠고기두부찜', '치커리유자청무침', '포기김치']
# ['밥', '우거지된장국', '쇠고기장조림', '옥수수전', '마늘쫑무침', '배추겉절이']
# ['밥', '고추장찌개', '훈제오리단호박볶음', '골뱅이무침', '양파절임/부추생채', '포기김치']
# ['밥', '얼큰순두부찌개', '짬뽕불고기', '잡채', '도토리묵무침', '포기김치']
# ['카레라이스', '우동국', '유린기', '메밀전병만두', '단무지/바나나', '포기김치']
# ['밥', '건새우아욱국', '등갈비김치말이', '계란말이', '숙주나물무침', '열무김치']
# ['나물비빔밥', '팽이장국', '생선까스', '갈비만두', '식혜', '포기김치']
# ['밥', '소고기미역국', '유자청제육볶음', '메추리알조림', '모듬쌈', '포기김치']
# ['밥', '된장찌개', '오징어볶음', '두부새싹구이', '파래김', '열무김치']
# ['마파두부덮밥', '맑은국', '치킨핑거', '시저샐러드', '무비트생채', '포기김치']
# ['밥', '매운콩나물국', '동파삼겹수육', '늙은호박전', '쫑상추무침', '배추겉절이']
# ['밥', '옥수수스프', '딸기드레싱샐러드', '감자범벅', '수제피클/음료', '포기김치']
# ['밥', '근대국', '소고기낙지볶음', '계란찜', '청경채사과생채', '포기김치']
# ['밥', '고추장찌개', '순살파닭', '감자채볶음', '콩나물무침', '포기김치']
# ['김치제육덮밥', '가쯔오장국', '시금치프리타타', '동태전', '오이무침', '열무김치']
# ['밥', '오징어국', '미니채소떡갈비', '멸치호두볶음', '물파래무침', '포기김치']
# ['야채볶음밥', '미역장국', '사천식탕수육', '멕시칸샐러드', '단무지', '포기김치']
# ['밥', '돈육김치찌개', '언양식불고기', '잡채', '진미채무침', '포기김치']
# ['밥', '차돌된장찌개', '주꾸미볶음', '옥수수전', '양념깻잎지', '포기김치']
# ['곤드레밥', '맑은국', '돈육강정', '사과고구마그라탕', '오복지무침', '배추겉절이']
# ['밥', '콩나물국', '해물누룽지탕', '모듬소시지구이', '미역레몬초무침', '포기김치']
# ['김치볶음밥', '나가사끼짬뽕국', '치킨텐더샐러드', '또띠아칩', '피클/방울토마토', '포기김치']
# ['밥', '김치콩나물국', '소고기장조림', '시금치프리타타', '오이무침', '포기김치']
# ['밥', '육개장', '탕수어', '온두부', '참나물', '김치볶음']
# ['콩나물밥', '미소장국', '닭강정', '청포묵무침', '오이도라지무침', '포기김치']
# ['밥', '된장찌개', '류산슬', '비빔야채만두', '실곤약흑임자무침', '포기김치']
# ['카레덮밥', '맑은국', '생선까스', '쫄면야채무침', '아몬드멸치볶음/과일', '포기김치']
# ['밥', '고추장찌개', '버섯불고기', '계란말이', '아삭고추무침', '포기김치']
# ['밥', '김치두부국', '누룽지탕수육', '마파두부', '파래김', '깍두기']
# ['나물비빔밥', '맑은국', '감자치즈구이', '군만두', '치커리유자청생채', '포기김치']
# ['밥', '아욱국', '닭볶음탕', '해물파전', '청경채생채', '열무김치']
# ['오므라이스', '미소장국', '모듬튀김', '콘샐러드', '군고구마/과일', '포기김치']
# ['밥', '열무된장국', '훈제오리구이', '우엉잡채', '양파절임/쌈무', '포기김치']
# ['밥', '홍합탕', '마늘간장치킨', '부추전', '마늘쫑무침', '포기김치']
# ['김치볶음밥/계란', '팽이장국', '해물까스', '콥샐러드', '비트무생채/요플레', '열무김치']
# ['밥', '쇠고기샤브국', '닭갈비', '동태전', '가지나물', '포기김치']
# ['밥', '근대국', '수제돈가스', '계란찜', '양념깻잎지', '깍두기']
# ['밥', '들깨시래기국', '유자청돈육볶음', '콩나물겨자채', '시금치나물', '포기김치']
# ['밥', '매운소고기국', '유린기', '코다리조림', '치커리사과무침', '포기김치']
# ...
# ['밥', '열무된장국', '쇠고기장조림', '마파두부', '오이맛살초무침', '포기김치']
# ['밥', '순두부찌개', '함박스테이크', '계란찜', '콩나물무침', '포기김치']
# ['밥', '닭개장', '갈치구이', '비엔나케찹볶음', '셀프무쌈말이', '포기김치']
# ['김치볶음밥', '새우튀김우동', '고구마치즈구이', '홍시드레싱샐러드', '오이피클', '깍두기']
# ['참치주먹밥', '잔치국수', '쇠고기퀘사디아', '꽃맛살샐러드', '음료/단무지', '포기김치']
# ['밥', '쇠고기샤브국', '탕수어', '견과류조림', '양념깻잎지', '포기김치']
# ['밥', '참치김치찌개', '주꾸미볶음', '계란말이', '쫑상추무침', '포기김치']
# ['야채볶음밥', '유부주머니국', '통새우또띠아', '야채쫄면무침', '과일', '깍두기']
# ['밥', '된장찌개', '꽁치구이', '모듬소세지구이', '오이무침', '포기김치']
# ['밥', '떡만두국', '닭매운찜', '김치전', '간장깻잎지/콘샐러드', '포기김치']
# ['밥', '부대찌개', '후르츠탕수육', '오징어초무침', '애호박나물', '포기김치']
# ['밥', '어묵국', '언양식불고기', '맛살냉채', '도라지오이무침', '포기김치']
# ['김밥', '잔치국수', '떡볶이', '김말이튀김', '음료', '배추겉절이']
# ['밥', '열무된장국', '소고기버섯볶음', '부추호박전', '브로콜리', '포기김치']
# ['해물굴소스볶음밥', '맑은국', '돈육간장강정', '흑임자시금치샐러드', '무우짱아찌', '포기김치']
# ['밥', '차돌박이찌개', '류산슬', '비엔나감자조림', '아삭고추무침', '포기김치']
# ['밥', '짬뽕국', '가자미카레튀김', '고기전', '치커리무침', '포기김치']
# ['오므라이스', '미니우동', '닭오븐구이', '고구마튀김', '꼬들단무지', '포기김치']
# ['']
# ['참치회덮밥', '미소장국', '또띠아피자', '꽃맛살샐러드', '락교/과일', '포기김치']
# ['밥', '떡국', '돈육장조림', '해물김치전', '참나물생채', '깍두기']
# ['밥', '열무된장국', '함박스테이크', '닭살겨자냉채', '마늘쫑무침', '포기김치']
# ['멸치주먹밥', '해물수제비', '야채튀김', '오징어숙회무침', '오복지', '깍두기']
# ['밥', '닭개장', '황태양념구이', '고추잡채', '톳두부무침', '포기김치']
# ['목살필라프', '계란국', '로제파스타', '양배추샐러드', '해쉬포테이토', '포기김치']
# ['밥', '들깨시래기국', '대패삼겹', '두부양념조림', '무생채', '배추겉절이']
# ['밥', '얼갈이국', '훈제오리불고기', '두부구이', '부추생채/쌈무', '포기김치']
# ['유부초밥', '쌀국수', '쇠고기퀘사디아', '단무지', '사과푸딩', '포기김치']
# ['밥', '해물순두부찌개', '등갈비바베큐조림', '고등어구이', '오이생채', '포기김치']
# ['밥', '설렁탕', '부추전', '오징어젓무침', '야채스틱/과일', '석박지']
# ['밥', '부대찌개', '소불고기', '새송이버섯볶음', '꽃상추무침', '열무김치']
# ['밥', '열무된장국', '짬뽕불고기', '버섯들깨나물', '양배추쌈', '포기김치']
# ['통새우김밥', '우동', '찹쌀순대볶음', '딸기드레싱샐러드', '양배추피클', '포기김치']
# ['밥', '얼갈이된장국', '삼겹살구이', '어묵꽈리고추볶음', '상추파무침', '포기김치']
# ['밥', '뼈감자탕', '유린기', '궁중떡볶음', '단호박팥찜', '깍두기']
# ['밥', '쇠고기샤브국', '미트볼조림', '맛살전', '모듬묵', '열무김치']
# ['밥', '미역국', '삼겹보쌈', '김치전', '무말랭이', '배추겉절이']
# ['닭갈비볶음밥', '가쯔오장국', '크림카레우동', '수제고로케', '오이피클', '포기김치']
# ['']
# ['참치주먹밥', '잔치국수', '오징어튀김', '과일샐러드', '단무지', '포기김치']
# ['밥', '소고기무국', '굴비구이', '비엔나케찹볶음', '셀프무쌈말이', '포기김치']
# ['밥', '옹심이만두국', '오징어볶음', '두부계란부침', '물미역초무침', '포기김치']
# ['짜장면/작은밥', '계란국', '미니햄버거', '고구마맛탕', '오복지무침', '포기김치']
# ['밥', '매운버섯국', '돈육강정', '물파래전', '오이사과무침', '포기김치']
# ['꼬마김밥', '우동', '케이준샐러드', '단호박범벅', '무피클', '포기김치']
# ['밥', '연두부탕', '함박스테이크', '실곤약초무침', '건파래무침', '포기김치']
# ['밥', '감자국', '닭데리야끼조림', '매운어묵볶음', '참나물땅콩가루무침', '포기김치']
# ['참치마요덮밥', '꼬지어묵탕', '해물떡볶이', '키위드레싱샐러드', '단무지무침', '포기김치']
# ['밥', '북어계란국', '버섯불고기', '주꾸미초무침', '김구이', '열무김치']
# ['새우볶음밥', '맑은국', '깐풍육', '또띠아피자', '장아찌/피크닉', '포기김치']
# ['밥', '고추장찌개', '미니떡갈비조림', '해물동그랑땡', '유채나물', '포기김치']
# ['밥', '황태국', '양념치킨', '계란말이', '오이도라지생채', '포기김치']
# ['야채주먹밥', '잔치국수', '복주머니딤섬', '야채튀김', '요플레', '포기김치']
# ['밥', '김치국', '돈육간장볶음', '브로컬리새우전', '연근샐러드', '열무김치']
# ['밥', '설렁탕', '해물전', '오징어젓무침', '야채스틱/과일', '석박지']
# ['밥', '부대찌개', '오징어볶음', '계란찜', '모듬묵', '포기김치']
# ['밥', '닭개장', '주꾸미볶음', '고기전', '땅콩조림', '포기김치']
# ['굴소스볶음밥', '토마토스파게티', '크림스프', '마늘빵/감자튀김', '수제오이피클', '요구르트', '포기김치']
# ['빠에야', '쌀국수', '새우또띠아', '양배추샐러드', '군고구마', '포기김치']
# ['밥', '매운버섯국', '굴비구이', '버섯잡채', '아삭고추무침', '배추겉절이']
# ['밥', '소고기무국', '고등어구이', '마파두부', '무생채', '포기김치']
# ['']
# ['카레라이스', '맑은국', '생선까스', '멕시칸샐러드', '오복지무침', '포기김치']
# ['밥', '수제비국', '돈육장조림', '실곤약초무침', '세발나물', '포기김치']
# ['밥', '열무된장국', '해물누룽지탕', '모듬소시지구이', '미역레몬초무침', '포기김치']
# ['참치주먹밥', '우동', '새우까스', '고구마샐러드', '단무지무침', '포기김치']
# ['밥', '소고기무국', '주꾸미볶음', '계란찜', '애호박나물', '포기김치']
# ['작은밥', '옛날돈가스', '양송이스프', '양배추샐러드/모닝빵', '수제피클', '포기김치']
# ['밥', '청국장찌개', '소고기장조림', '김치전', '청경채겉절이', '포기김치']
# ['밥', '돈육김치찌개', '소고기숙주볶음', '계란찜', '유채나물', '배추겉절이']
# ['유부초밥', '쌀국수', '떡볶이', '군만두', '귤/음료', '포기김치']
# ['밥', '시금치국', '돈육고추장볶음', '잡채', '파채', '포기김치']
# ['쇠고기볶음밥', '팽이장국', '탕수육', '쫄면야채무침', '바나나', '포기김치']
# ['밥', '짬뽕국', '미니떡갈비조림', '매생이전', '참나물겉절이', '포기김치']
# ['밥', '만두국', '간장불고기', '옥수수전', '물파래무침', '배추겉절이']
# ['스팸주먹밥', '해물칼국수', '감자만두', '딸기드레싱샐러드', '무피클', '포기김치']
# ['밥', '된장찌개', '주꾸미삼겹살볶음', '셀프무쌈말이', '얼갈이나물', '포기김치']
# ['밥', '뼈감자탕', '해물파전', '고추,양파/쌈장', '부추생채', '귤', '석박지']
# ['오므라이스', '미소장국', '깐풍육', '감자튀김', '단무지무침', '석박지']
# ['자기개발의날']
# ['참치회덮밥', '우동', '수제고로케', '콘샐러드', '락교', '포기김치']
# ['밥', '매운콩나물국', '돈육장조림', '맛살전', '양념깻잎지', '포기김치']
# ['밥', '시래기국', '유린기', '연두부', '물파래무침', '포기김치']
# ['멸치주먹밥', '잔치국수', '해물까스', '매쉬드포테이토', '무피클', '포기김치']
# ['밥', '닭곰탕', '오징어볶음', '오꼬노미야끼계란말이', '가지나물', '배추겉절이']
# ['카레덮밥', '맑은국', '쫄면야채무침', '야채튀김', '단무지무침', '포기김치']
# ['밥', '콩나물국', '제육볶음', '동그랑땡전', '시래기조림', '포기김치']
# ['밥', '들깨버섯탕', '고추잡채&꽃빵', '시금치프리타타', '청경채겉절이', '포기김치']
# ['짜장잡채덮밥', '계란파국', '참치야채전', '꽃맛살샐러드', '오이사과무침', '포기김치']
# ['밥', '육개장', '류산슬', '연근튀김', '시금치나물', '포기김치']
# ['밥', '설렁탕', '부추전', '오징어젓무침', '야채스틱/과일', '석박지']
# ['밥', '김치찌개', '수제돈가스&소스', '맛살냉채', '애호박새우젓볶음', '열무김치']
# ['밥', '대구탕', '안동찜닭', '해물김치전', '취나물', '깍두기']
# ['통새우김밥', '우동', '계란떡볶이', '키위드레싱샐러드', '수제피클', '포기김치']
# ['밥', '순두부찌개', '해물누룽지탕', '닭가슴살냉채', '양배추쌈', '배추겉절이']
# ['파인애플볶음밥', '맑은국', '새우까스', '메추리알조림', '오복지무침', '포기김치']
# ['밥', '닭개장', '고등어구이', '두부스테이크', '부추겉절이', '포기김치']
# ['밥', '소고기무국', '가자미카레튀김', '비엔나케찹볶음', '셀프무쌈말이', '포기김치']
# ['야채볶음밥', '김치말이국수', '소고기퀘사디아', '멕시칸샐러드', '무피클', '포기김치']
# ['자기개발의날']
# ['짜장면/작은밥', '계란국', '사천식탕수육', '개성감자만두', '단무지', '포기김치']
# ['밥', '콩나물국', '돼지갈비찜', '옥수수전', '청경채생채', '포기김치']
# ['밥', '쑥된장국', '삼겹살구이', '어묵볶음', '봄동쌈', '포기김치']
# ['김치볶음밥', '유부장국', '로제스파게티', '콥샐러드', '오이무피클', '포기김치']
# ['밥', '해물된장찌개', '미니채소떡갈비', '시금치프리타타', '취나물된장볶음', '포기김치']
# ['유부초밥', '칼국수', '순대야채볶음', '야채튀김', '시금치샐러드', '포기김치']
# ['밥', '나가사키짬뽕국', '모듬버섯탕수육', '두부조림', '생파김치', '포기김치']
# ['밥', '콩가루배추국', '동파육', '두부새싹구이', '콩나물파채무침', '포기김치']
# ['유산슬덮밥', '계란파국', '멘보샤', '짜샤이볶음', '미나리나물무침', '포기김치']
# ['밥', '부대찌개', '등갈비오븐구이', '쫄면비빔만두', '키위그린샐러드', '포기김치']
# ['버섯영양밥', '물만두국', '메추리알치즈떡볶이', '건파래볶음', '얼갈이나물된장무침', '포기김치']
# ['밥', '청국장찌개', '닭불고기', '해물동그랑땡전', '오이쑥갓겉절이', '포기김치']
# ['밥', '열무된장국', '묵은지닭찜', '수수부꾸미', '무생채', '포기김치']
# ['밥', '해물손수제비', '미트볼피망볶음', '달래오이생채', '낙지젓무침', '포기김치']
# ['밥', '돈육김치찌개', '코다리강정', '간장계란장', '참나물들깨무침', '깍두기']
# ['밥', '옛날돈까스', '팽이장국', '콘치즈구이', '수제피클/오렌지', '포기김치']
# ['밥', '건새우아욱국', '치즈함박스테이크', '고등어구이', '부추팽이겉절이', '포기김치']
# ['밥', '닭개장', '삼치튀김', '한식잡채', '파김치', '포기김치']
# ['오므라이스', '가쯔오장국', '돈육고구마강정', '과일플레인샐러드', '단무지무침', '포기김치']
# ['밥', '장각닭죽', '생야채', '오렌지', '하루야채주스', '포기김치']
# ['멸치주먹밥', '우동', '해물까스', '꽃맛살샐러드', '무피클/요구르트', '포기김치']
# ['밥', '시금치국', '언양식불고기', '꽁치감자조림', '봄동겉절이', '포기김치']
# ['밥', '무채국', '더덕고추장불고기', '두부카프레제샐러드', '청포묵무침', '배추겉절이']
# ['충무김밥', '메밀국수', '오징어어묵무침', '단무지', '베리베리퐁당요플레', '석박지']
# ['밥', '쇠고기샤브국', '통마늘너비아니조림', '녹두빈대떡', '브로컬리', '포기김치']
# ['마늘베이컨볶음밥', '크림스프', '비프스파게티', '사과양상추샐러드', '바게뜨', '포기김치']
# ['밥', '참치김치찌개', '소고기메추리알장조림', '맛살냉채', '무채유자무침', '배추겉절이']
# ['밥', '배추된장국', '칠리미트볼조림', '김치미나리전', '도토리묵무침', '포기김치']
# ['참치마요덮밥', '어묵국', '고구마떡볶이', '자몽샐러드', '단무지무침', '포기김치']
# ['밥', '부대찌개&쫄면사리', '꽁치한마리구이', '감자전', '청경채김치', '포기김치']
# ['스팸볶음밥', '가쓰오장국', '삼겹살야채비빔면', '옥수수볼맛탕', '무피클', '포기김치']
# ['밥', '된장찌개', '매운돼지갈비찜', '그린빈베이컨볶음', '멸치견과류볶음', '포기김치']
# ['밥', '순두부찌개', '돈육두릅장조림', '맛살전', '오이무침', '포기김치']
# ['작은밥', '백종원의', '고추짜장', '맑은국', '칠리베이비크랩', '시금치흑임자샐러드', '단무지', '포기김치']
# ['불고기필라프', '미소장국', '닭봉오븐구이', '그린요거트샐러드', '수제오이피클', '포기김치']
# ['밥', '뼈없는감자탕', '달래새우전', '야채부케', '오징어젓갈무침', '포기김치']
# ['밥', '돈육김치찌개', '고등어카레구이', '마파두부', '콩나물파채무침', '포기김치']
# ['밥', '두부미소된장국', '오리훈제마늘볶음', '무쌈깻잎', '코다리강정', '오이소박이', '포기김치']
# ['밥', '굴미역국', '오삼불고기', '스팸,깻잎전', '쪽파김무침', '포기김치']
# ['밥', '조갯살아욱국', '함박스테이크', '삼치데리야끼', '청포묵야채무침', '포기김치']
# ['밥', '나가사끼짬뽕국', '순대야채볶음', '꼬치어묵떡볶이', '짜사이채무침', '포기김치']
# ['밥', '감자만두국', '꽃삼겹김치찜', '꿔바로우탕수육', '해파리냉채', '토마토설탕절인', '깍두기']
# ['밥', '황태미역국', '매운돈갈비찜', '두부/김치볶음', '유채나물된장무침', '무생채']
# ['밥', '홍합무우국', '로제찜닭', '계란장조림', '숙주미나리무침', '연근흑임자샐러드', '배추김치']
# ['밥', '다슬기아욱국', '갈릭파닭', '돈채호박볶음', '짠지오이무침', '요구르트', '포기김치']
# ['땡초주먹밥', '근대두부된장국', '치킨텐더', '루꼴라샐러드', '쫑상추새콤무침', '망고주스', '포기김치']
# ['밥', '우삼겹부대찌개', '조기구이', '수제어묵볶음', '섬초무침', '배추겉절이']
# ['김치볶음밥', '유부된장국', '새우로제파스타', '계란후라이', '취나물무침', '요구르트', '포기김치']
# ['부채살오므라이스', '가쓰오장국', '닭윙강정튀김', '새우미역초무침', '파인애플주스', '포기김치']
# ['밥', '전주식콩나물국', '', '안동찜닭', '가자미구이', '브로컬리초회', '포기김치']
# ['밥', '얼큰동태탕', '물만두탕수', '닭가슴살장조림', '오이선', '포기김치']
# ['밥', '삼선짬뽕국', '춘장돈육볶음', '어묵잡채볶음', '참나물무침', '배추겉절이']
# ['밥', '계란파국', '매운등뼈조림', '동그랑땡전', '부추팽이무침', '포기김치']
# ['밥', '아욱국', '깐풍기', '깻잎전', '사과오이생채', '포기김치']
# ['계란김밥', '모듬어묵탕', '고구마맛탕', '꽃맛살샐러드', '배/', '음료', '깍두기']
# ['밥', '매운버섯국', '고등어구이', '돈육잡채', '치커리깨소스무침', '포기김치']
# ['야채볶음밥', '김치우동', '또띠아피자', '비타민흑임자샐러드', '수제오이피클', '포기김치']
# ['밥', '된장찌개', '고구마까스', '샐러리샐러드', '김구이', '포기김치']
# ['밥', '소고기된장찌개', '해물누룽지탕', '김치고기전', '매운콩나물무침', '포기김치']
# ['김밥볶음밥', '미소장국', '로제파스타', '회오리감자', '상추부추무침', '포기김치']
# ['밥', '도토리묵냉국', '돼지갈비찜', '감자프리타타', '오이도라지무침', '포기김치']
# ['밥', '돼지국밥', '고추튀김', '야채스틱/부추무침', '음료', '포기김치']
# ['밥', '해물순두부국', '닭가슴살겨자무침', '메밀전병만두', '가지나물', '포기김치']
# ['밥', '청국장찌개', '소고기불고기', '실곤약야채무침', '감자채볶음', '포기김치']
# ['유부초밥', '새우튀김우동', '과일샐러드', '찐옥수수', '단무지', '포기김치']
# ['밥', '닭곰탕', '류산슬', '비엔나감자구이', '미역초무침', '포기김치']
# ['밥', '감자국', '미트볼조림', '브로컬리오징어숙회', '부추오리엔탈무침', '포기김치']
# ['밥', '오징어국', '매운닭찜', '도토리묵야채무침', '멸치볶음', '포기김치']
# ['밥', '김치두부국', '갈치튀김', '햄계란말이', '청경채생채', '포기김치']
# ['삼겹살마늘볶음밥', '콩나물국', '미니돈까스', '양상추메추리알샐러드', '꽈배기도너츠/요구르트', '포기김치']
# ['밥', '근대국', '돈육간장볶음', '동태포전', '치커리배생채', '포기김치']
# ['야채볶음밥', '초계국수', '코코넛새우튀김', '옥수수콘치즈', '음료', '포기김치']
# ['밥', '부대찌개', '떡갈비조림', '쫄면무침', '무나물들깨볶음', '포기김치']
# ['밥', '돈육김치찌개', '깐풍기', '고갈비구이', '가지된장무침', '포기김치']
# ['김밥', '미니우동', '구슬떡볶이', '김말이,고추튀김', '다시마채무초무침', '포기김치']
# ['밥', '김치어묵국', '케이준샐러드', '섭산적표고굴소스볶음', '매운콩나물무침', '포기김치']
# ['밥', '스팸김치찌개', '동태포전', '새송이버섯장조림', '열무된장나물', '포기김치']
# ['오므라이스', '유부장국', '깐쇼새우', '꽃맛살샐러드', '채소피클', '포기김치']
# ['밥', '대구지리', '바베큐함박찹스테이크', '건파래볶음', '치커리무침', '포기김치']
# ['후리가케덮밥', '잔치국수', '채소튀김', '쇠고기우엉볶음', '양념고추지무침', '깍두기']
# ['밥', '된장찌개', '아귀콩나물찜', '부들어묵볶음', '노각무침', '포기김치']
# ['밥', '뼈감자탕', '쌈추전', '오징어땅콩조림', '부추생채무침', '포기김치']
# ['밥', '김치콩나물국', '닭카레볶음', '볼어묵고추장볶음', '참나물무침', '포기김치']
# ['밥', '유부주머니된장국', '돈육간장볶음', '비빔만두', '꼬시래기초무침', '갓김치']
# ['밥', '매운계란파국', '오리훈제마늘볶음', '코다리강정', '돈나물오리엔탈무침', '포기김치']
# ['밥', '들깨시래기국', '묵은지닭찜', '미역줄기볶음', '얼갈이된장무침', '포기김치']
# ['채소볶음밥&자장소스', '고기짬뽕국', '해물누룽지', '군만두', '짜사이볶음', '포기김치']
# ['밥', '부대찌개', '생선까스', '감자채파프리카볶음', '고춧잎무침', '깍두기']
# ['유부초밥', '우동국물', '열무비빔국수', '소떡소떡', '가지나물', '포기김치']
# ['밥', '나박물김치', '매운사태찜', '김계란말이', '청경채겉절이', '포기김치']
# ['밥', '만둣국', '갈치무조림', '감자전', '상추무침', '포기김치']
# ['밥', '청국장찌개', '섭산적고추장구이', '느타리버섯볶음', '참나물무침', '포기김치']
# ['우육비빔냉면', '밥', '사골파국', '도넛츠/비트채소절임', '숙주나물/요구르트', '석박지']
# ['밥', '참치파개장', '오징어불고기', '이색전(가지,애호박)', '생깻잎지', '포기김치']
# ['타워함박스테이크', '밥', '알리오올리오파스타', '샐러드', '도라지오이초무침', '포기김치']
# ['밥', '짬뽕순두부찌개', '꽁치양파조림', '취나물볶음', '노각무침', '포기김치']
# ['밥', '꽃게탕', '춘천닭갈비', '탕평채', '땅콩멸치조림', '포기김치']
# ['밥', '계란파국', '고구마치즈돈까스', '쫄면채소무침', '미역줄기볶음', '석박지']
# ['오리훈제볶음밥', '미소장국', '샤워크림새우', '두부양념조림', '부추팽이버섯생채무침', '포기김치']
# ['밥', '감자만두국', '등심찹쌀꿔바로우', '코다리무조림', '시금치초고추장무침', '포기김치']
# ['폭탄주먹밥', '꼬치어묵국', '매운떡볶이', '순대찜', '포기김치']
# ['카레라이스', '우동국물', '비빔채소만두', '포테이토오븐구이', '오이무침', '포기김치']
# ['밥', '아욱국', '묵은지닭볶음탕', '콘치즈', '건파래볶음', '포기김치']
# ['밥', '두부된장찌개', '돈육고추장불고기', '채소쌈', '청양해물파전', '포기김치']
# ['밥', '소고기무국', '삼치엿장구이', '감자햄조림', '깻순나물', '포기김치']
# ['계란볶음밥', '숙주고기짬뽕', '고추잡채', '연유꽃빵튀김', '짜사이볶음', '포기김치']
# ['쇠고기규동덮밥', '미소장국', '숯불양념꼬치어묵', '오이볶음', '영양부추무침', '석박지']
# ['청양멸치주먹밥', '유부우동국물', '비빔칼국수', '새우만두', '콩나물무침', '포기김치']
# ['밥', '오징어무국', '치킨까스', '연근조림', '취나물무침', '포기김치']
# ['밥', '김치수제비국', '갈치조림', '녹두빈대떡', '브로콜리숙회', '포기김치']
# ['산채비빔밥', '팽이장국', '주꾸미볶음', '고추튀김', '계란후라이', '포기김치']
# ['밥', '감자고추장찌개', '언양식바싹불고기', '자반고등어구이', '꼬시래기무침', '포기김치/요구르트']
# ['밥', '냉메밀소바', '돈육가지두반장볶음', '새우튀김', '연두부', '포기김치']
# ['밥', '잡채말이어묵국', '오리훈제마늘볶음', '토마토계란찜', '고들빼기무침', '포기김치']
# ['밥', '콩가루배추국', '아쿠아돈까스', '밀떡볶이/허니슈스트링감자', '생깻잎지', '포기김치']
# ['밥', '김치두부국', '제육간장불고기', '감자채카레볶음', '통고추쌈장무침', '포기김치']
# ['밥', '육개장', '가자미엿장구이', '오꼬노미계란말이', '깍둑오이초무침', '포기김치']
# ['밥', '미역국', '닭볶음탕', '돈채표고버섯볶음', '꼬들단무지무침', '포기김치/요구르트']
# ['밥', '유부주머니우동국', '새우까스', '꽈리고추찹쌀무침', '비트피클', '포기김치']
# ['밥', '부대찌개', '꽁치한마리구이', '감자양념조림', '두부계란전', '포기김치']
# ['밥', '얼큰감자국', '안동찜닭', '옥수수맛살전', '도토리묵채소무침', '포기김치']
# ['밥', '열무된장국', '우불고기', '치커리무침', '포기김치']
# ['밥', '동태매운탕', '궁중떡볶이', '해초레몬무침', '청경채나물', '포기김치']
# ['충무김밥', '우동장국', '오징어무침', '채소튀김', '수제무말랭이무침', '포기김치/요구르트']
# ['밥', '소고기무국', '삼치구이', '마늘쫑메추리알조림', '매콤시래기된장지짐', '포기김치']
# ['밥', '미역국', '오징어채소볶음', '쪽파김무침', '포기김치']
# ['밥', '얼갈이된장국', '닭간장볶음', '라볶이', '영양부추무침', '포기김치']
# ['밥', '매운닭개장', '소고기계란장조림', '타꼬야끼', '열무나물', '포기김치']
# ['밥', '스팸김치찌개', '수제돈까스', '수제마늘바게트', '가지무침', '깍두기']
# ['밥', '콩비지찌개', '갈치카레구이', '어묵잡채', '오이보트샐러드', '포기김치']
# ['밥', '소고기무국', '스팸계란말이', '풋고추양파무침', '포기김치']
# ['밥', '된장찌개', '우불고기', '어묵볶음', '진미채오이무침', '포기김치']
# ['채소라면', '김밥', '가래떡오븐구이', '꽃맛살샐러드', '단무지', '포기김치']
# ['밥', '홍합탕', '건도토리묵파프리카볶음', '연근깨소스무침', '포기김치']
# ['밥', '근대국', '고등어김치찜', '두부고기조림', '옛날소시지전', '포기김치']
# ['밥', '우거지된장국', '닭볶음탕', '섭산적데리야끼조림', '콩나물무침', '포기김치']
# ['밥', '된장찌개', '고구마치즈구이', '오이생채', '포기김치']
# ['밥', '콩나물국', '돈육김치볶음', '꼬시래기무침', '포기김치']
# ['밥', '매운순대국밥', '고추튀김', '채소스틱', '애호박새우젓나물', '겉절이김치']
# ['밥', '쇠고기무국', '시래기삼치조림', '계란찜', '사과청경채무침', '포기김치']
# ['밥', '유부주머니된장국', '돈사태떡찜', '마카로니치즈범벅', '고들빼기무침', '포기김치']
# ['밥', '배추된장국', '닭간장조림', '미더덕콩나물찜', '마늘쫑볶음', '포기김치']
# ['밥', '어묵매운탕', '등심돈까스', '꽁치한마리구이', '얼갈이나물', '포기김치']
# ['미역국', '대패삼겹숙주볶음', '연두부계란찜', '상추무침', '포기김치']
# ['밥', '짬뽕국', '해물볶음우동', '매콤호박볶음', '포기김치']
# ['밥', '닭개장', '삼치구이', '건도토리묵파프리카볶음', '부추무침', '포기김치']
# ['우거지국', '김말이강정', '김치전', '해초무침', '포기김치']
# ['밥', '고추장찌개', '소불고기', '진미채무말랭이무침', '햄감자볶음', '포기김치/열무김치볶음']
# ['밥', '부대찌개', '샤워크림새우', '두부조림', '콘슬로우', '깍두기']
# ['밥', '아욱국', '고르곤졸라피자', '참나물초장무침', '포기김치/마늘바게트']
# ['밥', '순두부찌개', '제육춘장볶음', '오이보트샐러드', '상추', '포기김치']
# ['애플카레라이스', '우동국물', '숯불양념꼬치어묵', '단무지양념무침', '포기김치']
# ['밥', '사골옹심이만둣국', '스태프핫도그', '가자미양념찜', '쪽파김무침', '포기김치']
# ['김주먹밥', '잔치국수', '쇠고기육전', '콩나물무침', '양념고추지', '열무김치']
# ['밥', '컵라면&찐계란', '순대채소볶음', '근대고추장무침', '포기김치']
# ['밥', '열무된장국', '주꾸미채소볶음', '햄전&케찹', '건파래볶음', '포기김치']
# ['밥', '온모밀국수', '돈까스김치나베', '양배추샐러드&사우전D', '오이지무침', '무생채']
# ['밥', '콩나물국', '순살닭강정', '치즈계란찜', '감자간장조림', '포기김치']
# ['밥', '고기짬뽕국', '자반고등어찜', '시금치나물', '열무김치']
# ['오뗄햄김밥', '김치어묵탕', '백종원의사라다빵', '가지나물', '꼬들단무지', '포기김치']
# ['밥', '닭개장', '삼치데리야끼구이', '오이양파무침', '콩나물볶음', '포기김치']
# ['채소볶음밥', '유부장국', '자장소스', '한식잡채', '계란후라이/요구르트', '깍두기']
# ['밥', '김칫국', '간장마늘치킨', '감자채카레볶음', '얼갈이열무겉절이']
# ['밥', '꽃게탕', '우불고기볶음', '진미채오이무침', '가지나물', '포기김치']
# ['밥', '계란파국', '퀘사디아', '갈치무조림', '고구마순들깨볶음', '열무김치']
# ['밥', '옹심이만둣국', '꽁채캔김치조림', '감자채전', '연근깨소스무침', '열무김치']
# ['밥', '버섯육개장', '몽골식돈육볶음&꽃빵', '양념깻잎지', '마늘종멸치볶음', '포기김치']
# ['밥', '매운순대국', '오징어굴소스볶음', '동그랑땡강정', '고추지무침', '석박지']
# ['꼬치어묵매운탕', '밥', '채소볶음우동', '콘샐러드', '단무지무침', '포기김치']
# ['밥', '부대찌개', '생선까스', '김계란말이', '상추무침', '포기김치']
# ['밥', '쇠고기미역국', '방어양념장구이', '옥수수계란찜', '새우살호박볶음', '열무김치']
# ['밥', '청양콩나물국', '목살스테이크', '미나리무침', '오이보트샐러드', '포기김치']
# ['＜자기', '계발의', '날＞']
# ['밥', '우동국물', '치즈닭갈비/계란후라이', '깻잎쌈', '무생채']
# ['밥', '황태국수', '돈수육', '모둠채소무침', '풋고추/양파', '수제보쌈김치']
# ['밥', '동태탕', '감자채파프리카볶음', '세발나물무침', '포기김치']
# ['마파두부', '홍합짬뽕국', '샤워크림새우', '물만두찜', '짜사이볶음', '백김치']
# ['밥', '계란파국', '묵은지삼겹살찜', '궁중떡볶이', '참나물겉절이', '깍두기']
# ['밥', '맑은콩나물국', '이색묵(올방개/클로렐라)', '고구마순볶음', '포기김치']
# ['밥', '얼갈이된장국', '낙지볶음', '노가리고추조림', '미나리전', '겉절이김치']
# ['밥', '옹심이감자국', '치킨까스', '쇠고기가지조림', '상추무침', '포기김치']
# ['김치볶음밥', '미소된장국', '수제등심찹쌀꿔바로우', '계란후라이', '실곤약채소무침', '석박지']
# ['밥', '부대찌개', '해물볶음', '메추리알꽈리고추조림', '참나물무침', '포기김치']
# ['밥', '유부장국', '딤섬', '브로콜리숙회', '열무된장나물', '포기김치']
# ['밥', '컵라면&찐계란', '수제오징어튀김', '매운떡볶이', '단무지무침', '포기김치']
# ['밥', '꼬치어묵매운탕', '쇠고기청경채볶음', '새송이버섯조림', '깻잎고기전', '포기김치']
# ['고추잡채덮밥', '손수제비국', '자장소스', '단무지무침', '포기김치']
# ['밥', '쇠고기무국', '오징어떡볶음', '물파래초무침', '숙주미나리나물', '포기김치']
# ['밥', '순두부백탕', '제육간장불고기', '매운감자조림', '포기김치']
# ['밥', '맑은버섯닭개장', '참치김치볶음', '도토리묵', '쑥갓겉절이', '깍두기']
# ['팽이장국', '계란후라이', '도라지초무침', '김치볶음']
# ['밥', '아귀매운탕', '돈갈비찜', '오이선', '고구마순볶음', '포기김치']
# ['유부초밥', '들깨미역국', '페퍼로니치즈피자', '골뱅이채소무침&실곤약', '콩나물굴소스볶음', '포기김치']
# ['밥', '해물까스&타르타르D', '느타리버섯볶음', '치커리귤무침', '배추김치']
# ['밥', '부대찌개', '소고기콜라비조림', '코다리강정', '오이나물볶음', '포기김치']
# ['미니쌀국수', '춘권', '계란후라이', '양배추비트피클', '무생채']
# ['밥', '고기짬뽕국', '해물누룽지탕', '멸치마늘종조림', '단무지채무침', '포기김치']
# ['밥', '고추장찌개', '베이컨숙주볶음', '상추무침', '포기김치']
# ['밥', '감자양파국', '돈육김치볶음', '팽이버섯채소전', '미나리나물무침', '깍두기']
# ['밥', '옹심이국', '쇠고기숙주볶음', '야채전', '고구마연근맛탕', '포기김치']
# ['밥', '맑은버섯국', '순대들깨볶음', '가지마파두부', '돌나물유자청무침', '포기김치']
# ['밥', '가쓰오장국', '수제치킨까스', '팽이버섯부추무침', '산고추지무침', '무생채']
# ['밥', '홍합탕', '오삼불고기', '어묵깻잎전', '오이달래무침', '포기김치']
# ['밥', '순두부백탕', '닭볶음탕', '비빔만두채소무침', '명엽채볶음', '포기김치']
# ['밥', '배추된장국', '낙지미나리볶음', '메추리알풋고추조림', '시금치나물무침', '깍두기']
# ['밥', '북어짬뽕국', '만가닥버섯불고기', '건새우호박채전', '삼색귤소스무침', '포기김치']
# ['김치볶음밥', '미니쫄우동', '브로콜리깨소스무침', '계란후라이', '고들빼기무침', '겉절이김치']
# ['밥', '쇠고기무국', '삼치양념구이', '비엔나채소볶음', '숙주나물당근무침', '포기김치']
# ['밥', '수제비국', '수제맛쵸킹탕수육', '유부채소겨자냉채', '참나물무침', '갓김치/겉절이김치']
# ['밥', '열무된장국', '장어강정', '깻잎쌈', '오이선', '포기김치']
# ['잔치국수', '수제고기육전', '쑥갓나물', '양파초절임', '깍두기']

# %%
special_day_idx = df["석식메뉴"].str.contains("의날")
df.loc[special_day_idx, "석식메뉴"]
# Out:
# 327            자기계발의날
# 346          *자기계발의날*
# 366              가정의날
# 667          자기계발의날
# 706          자기계발의날
# 730          자기개발의날
# 747        *  자기계발의날  *
# 766        *  자기개발의날  *
# 786        *  자기계발의날  *
# 809        *  자기개발의날  *
# 828       *  자기개발의날  *
# 853          자기계발의날
# 973          자기개발의날
# 993          자기개발의날
# Name: 석식메뉴, dtype: object

# %%
df.loc[df["중식계"] == 0, "중식메뉴"]
# Out:
# Series([], Name: 중식메뉴, dtype: object)

# %%
df.loc[df["석식계"] == 0, "석식메뉴"]
# Out:
# 204                                            *
# 224                                            *
# 244                                             *
# 262                                            *
# 281                                            *
# 306                                            *
# 327                                         자기계발의날
# 346                                       *자기계발의날*
# 366                                           가정의날
# 392                                            *
# 410    쌀밥/잡곡밥 (쌀:국내산) 된장찌개  미니함박조림  계란말이  비름나물  포기김치 ...
# 412                                            *
# 424                                            *
# 449                                            *
# 468                                            *
# 492                                            *
# 502    쌀밥/잡곡밥 (쌀:국내산) 쇠고기무국  고추잡채*꽃빵  계란찜  오이무침  포기김치...
# 510                                            *
# 529                                              *
# 549
# 571
# 589                                             *
# 609
# 633                                            *
# 648
# 667                                       자기계발의날
# 687                                            *
# 706                                       자기계발의날
# 730                                       자기개발의날
# 747                                     *  자기계발의날  *
# 766                                     *  자기개발의날  *
# 786                                     *  자기계발의날  *
# 809                                     *  자기개발의날  *
# 828                                    *  자기개발의날  *
# 853                                       자기계발의날
# 872                                            *
# 890                                            *
# 912                                            *
# 932                                            *
# 955                                            *
# Name: 석식메뉴, dtype: object

# %%
df.loc[(df["석식계"] == 0 ) & df["석식메뉴"].str.contains("밥"), "석식계"] = df["석식계"].median()

# %%
df.loc[(df["석식계"] == 0 ), "석식메뉴"] = "석식없음"
df["석식없음"] = (df["석식메뉴"] == "석식없음").astype(int)

# %% [markdown]
# 메뉴의 메인과 국에 따른 ```중식계```, ```석식계```의 평균값의 rank를 계산하여 변수로 추출

# %%
def calc_rank(df, col_name, key, agg = 'mean'):
    rank = df.groupby(col_name)[key].agg(agg).rank(ascending = False)
    df[f'{col_name}_{key}_{agg}_rank'] = df[col_name].map(rank)
    df[f'{col_name}_{key}_{agg}_rank'] = df[f'{col_name}_{key}_{agg}_rank'].fillna(rank.median())
    return df

# %%
for col_name in ['중식메인', '중식국', '석식메인', '석식국', "연도분기", "요일"]:
    df = calc_rank(df, col_name, "중식계", 'mean')
    df = calc_rank(df, col_name, "석식계", 'mean')

# %%
df.head(2)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴  ...  중식국_중식계_mean_rank  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  ...               17.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...  ...               54.0
#
#    중식국_석식계_mean_rank  석식메인_중식계_mean_rank  석식메인_석식계_mean_rank  \
# 0              169.0               215.0               250.0
# 1               26.5                83.0                82.0
#
#    석식국_중식계_mean_rank  석식국_석식계_mean_rank 연도분기_중식계_mean_rank 연도분기_석식계_mean_rank  \
# 0              107.0              165.0                3.0                1.0
# 1               95.0              101.0                3.0                1.0
#
#   요일_중식계_mean_rank 요일_석식계_mean_rank
# 0              1.0              1.0
# 1              2.0              2.0
#
# [2 rows x 35 columns]

# %% [markdown]
# ## 머신러닝 모델링
# ### 모델에 들어가 변수 설정

# %%
df.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계', '연도', '분기', '월',
#        '일', '연도월', '연도분기', '중식메인', '중식국', '석식메인', '석식국', '석식없음',
#        '중식메인_중식계_mean_rank', '중식메인_석식계_mean_rank', '중식국_중식계_mean_rank',
#        '중식국_석식계_mean_rank', '석식메인_중식계_mean_rank', '석식메인_석식계_mean_rank',
#        '석식국_중식계_mean_rank', '석식국_석식계_mean_rank', '연도분기_중식계_mean_rank',
#        '연도분기_석식계_mean_rank', '요일_중식계_mean_rank', '요일_석식계_mean_rank'],
#       dtype='object')

# %% [markdown]
# 전처리 후 ```train```/```test``` 재분리

# %%
train, test = split_train_test(df, suffle=False)
display(train.head(2)), display(test.head(2))

train.shape, test.shape
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
#
#                                                 석식메뉴  ...  중식국_중식계_mean_rank  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  ...               17.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...  ...               54.0
#
#    중식국_석식계_mean_rank  석식메인_중식계_mean_rank  석식메인_석식계_mean_rank  \
# 0              169.0               215.0               250.0
# 1               26.5                83.0                82.0
#
#    석식국_중식계_mean_rank  석식국_석식계_mean_rank 연도분기_중식계_mean_rank 연도분기_석식계_mean_rank  \
# 0              107.0              165.0                3.0                1.0
# 1               95.0              101.0                3.0                1.0
#
#   요일_중식계_mean_rank 요일_석식계_mean_rank
# 0              1.0              1.0
# 1              2.0              2.0
#
# [2 rows x 35 columns]
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 964  2020-01-14  화   2821      96     236             388          0.0
# 965  2020-01-15  수   2821      97     235               4          0.0
#
#                                                   조식메뉴  \
# 964  모닝롤/바나나샌드  우유/주스 스크램블에그 흑임자죽/쌀밥 (쌀:국내산) 감자양파국 ...
# 965  모닝롤/치즈프레즐  우유/주스 계란후라이 누룽지탕/쌀밥 (쌀:국내산) 차돌박이찌개 ...
#
#                                                   중식메뉴  \
# 964  쌀밥/잡곡밥 (쌀:국내산) 시래기국  함박스테이크*소스  두부구이  오이무침  포기...
# 965  단호박영양밥 (쌀:국내산) 연두부탕  오징어숙회무침 (오징어:원양산) 고기전 (돼지...
#
#                                                   석식메뉴  ...  \
# 964  유부초밥 (쌀:국내산) 쌀국수 (양지:호주산) 떡볶이  군만두  귤/음료  포기김치...  ...
# 965  쌀밥/잡곡밥 (쌀:국내산) 시금치국  돈육고추장볶음  잡채  파채*소스/쌈무  포기...  ...
#
#      중식국_중식계_mean_rank  중식국_석식계_mean_rank  석식메인_중식계_mean_rank  \
# 964               60.0              123.0               129.0
# 965               93.0               99.0                 2.0
#
#      석식메인_석식계_mean_rank  석식국_중식계_mean_rank  석식국_석식계_mean_rank  \
# 964                45.5               91.0               87.0
# 965                 3.5              177.0              152.5
#
#     연도분기_중식계_mean_rank 연도분기_석식계_mean_rank 요일_중식계_mean_rank 요일_석식계_mean_rank
# 964               15.0               17.0              2.0              2.0
# 965               15.0               17.0              3.0              5.0
#
# [2 rows x 35 columns]
# ((964, 35), (241, 35))

# %%
label_names = ["중식계", "석식계"]

# %% [markdown]
# feature engineering 후 변수들과의 상관크기 확인(절대값)

# %%
corr_mat = corr_with_target(df, target_col = label_names, size = (20, 5), absolute = True, rtn = True)

# %%
corr_mat
# Out:
#                          중식계       석식계
# 요일_중식계_mean_rank    0.734024  0.263406
# 중식메인_중식계_mean_rank  0.595876  0.198745
# 석식메인_중식계_mean_rank  0.575981  0.329625
# 본사시간외근무명령서승인건수      0.527860  0.562290
# 요일_석식계_mean_rank    0.508094  0.451887
# 본사출장자수              0.497746  0.162214
# 석식국_중식계_mean_rank   0.474572  0.315893
# 중식국_중식계_mean_rank   0.461192  0.213698
# 본사휴가자수              0.403945  0.295695
# 석식메인_석식계_mean_rank  0.311116  0.624250
# 중식메인_석식계_mean_rank  0.307712  0.549434
# 연도분기_중식계_mean_rank  0.273834  0.229969
# 석식국_석식계_mean_rank   0.266494  0.583819
# 중식국_석식계_mean_rank   0.250100  0.484467
# 연도분기_석식계_mean_rank  0.242188  0.274938
# 월                   0.186995  0.147742
# 분기                  0.184442  0.150409
# 본사정원수               0.155740  0.152896
# 연도                  0.142359  0.180487
# 일                   0.100628  0.224041
# 석식없음                0.056085  0.704068
# 현본사소속재택근무자수         0.014995  0.027682

# %% [markdown]
# 인원에 관한 변수들과 feature engineering으로 얻어진 변수들을 최종 feature로 결정

# %%
feature_names = train.columns[train.columns.str.contains('수|mean|석식없음')].tolist()
feature_names
# Out:
# ['본사정원수',
#  '본사휴가자수',
#  '본사출장자수',
#  '본사시간외근무명령서승인건수',
#  '현본사소속재택근무자수',
#  '석식없음',
#  '중식메인_중식계_mean_rank',
#  '중식메인_석식계_mean_rank',
#  '중식국_중식계_mean_rank',
#  '중식국_석식계_mean_rank',
#  '석식메인_중식계_mean_rank',
#  '석식메인_석식계_mean_rank',
#  '석식국_중식계_mean_rank',
#  '석식국_석식계_mean_rank',
#  '연도분기_중식계_mean_rank',
#  '연도분기_석식계_mean_rank',
#  '요일_중식계_mean_rank',
#  '요일_석식계_mean_rank']

# %%
X_train = train[feature_names]
X_test = test[feature_names].reset_index(drop = True)
y_train = train[label_names]
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((964, 18), (964, 2), (241, 18), (241, 2))

# %% [markdown]
# ### DNN 모델
# 예측치 두개를 각각 예측하기 위해 1개의 Ouput을 가지는 ```model```을 만들고 ```model_lnch```, ```model_dnr```로 clone함

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation = 'relu', input_shape =[len(X_train.keys())]),
    tf.keras.layers.Dense(128, activation = 'swish'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(512, activation = 'swish'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(128, activation = 'swish'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64, activation = 'relu'), 
    tf.keras.layers.Dense(16, activation = 'swish'),
    tf.keras.layers.Dense(1), 

])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1216
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dense_3 (Dense)             (None, 512)               131584
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 16)                1040
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 350,753
# Trainable params: 349,217
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
model_lnch = tf.keras.models.clone_model(model)
model_dnr = tf.keras.models.clone_model(model)

# %%
# dir(tf.optimizers)

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate = 1e-2,
                                                          decay_steps = 10000,
                                                          decay_rate = 0.9)

# %%
optimizer = tf.keras.optimizers.Adam(
    learning_rate=lr_schedule,
)

# %%
model_lnch.compile(optimizer= optimizer, loss = "mae", metrics=["mse","mae"])
model_dnr.compile(optimizer= optimizer, loss = "mae", metrics=["mse","mae"])

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience= 100)

# %%
history_lnch = model_lnch.fit(X_train, y_train["중식계"], epochs= 300, batch_size = 32, validation_split= 0.3,  callbacks= [early_stop],  verbose = 0)
history_dnr = model_dnr.fit(X_train, y_train["석식계"], epochs= 300, batch_size = 32, validation_split= 0.3,  callbacks= [early_stop],  verbose = 0)

# %%
df_hist_lnch = pd.DataFrame(history_lnch.history)
df_hist_lnch.tail()
# Out:
#           loss           mse        mae    val_loss       val_mse     val_mae
# 276  80.591393  10518.811523  80.591393   84.433426  11825.187500   84.433426
# 277  76.986992   9816.848633  76.986992   88.859451  13881.864258   88.859451
# 278  72.897026   9000.025391  72.897026   76.239098  10395.768555   76.239098
# 279  79.983307  10956.969727  79.983307  107.229538  17195.007812  107.229538
# 280  79.334732  10121.867188  79.334732   85.169724  12195.599609   85.169724

# %%
df_hist_dnr = pd.DataFrame(history_dnr.history)
df_hist_dnr.tail()
# Out:
#           loss          mse        mae    val_loss       val_mse     val_mae
# 295  60.811798  8506.635742  60.811798  177.011047  43924.765625  177.011047
# 296  60.243961  7940.818359  60.243961  149.198822  34265.996094  149.198822
# 297  61.808239  8429.915039  61.808239  102.994682  20642.898438  102.994682
# 298  58.034420  6885.025391  58.034420   97.615250  18073.275391   97.615250
# 299  59.157478  7022.600098  59.157478  103.260117  17213.845703  103.260117

# %%
y_predict = pd.DataFrame(np.column_stack((model_lnch.predict(X_test), model_dnr.predict(X_test))), columns = label_names)

# %%
display(y_test, y_predict)
# Out:
#         중식계    석식계
# 0     820.0  272.0
# 1     633.0  350.0
# 2     761.0  457.0
# 3     696.0  344.0
# 4    1075.0  439.0
# ..      ...    ...
# 236  1093.0  421.0
# 237   832.0  353.0
# 238   579.0  217.0
# 239  1145.0  502.0
# 240  1015.0  480.0
#
# [241 rows x 2 columns]
#              중식계         석식계
# 0     979.236877  587.051208
# 1     852.728516  495.964417
# 2     949.932983  580.531128
# 3     618.115173  439.085266
# 4    1088.440063  588.254211
# ..           ...         ...
# 236   908.092285  587.366699
# 237   960.169861  647.613464
# 238   657.177429  560.393799
# 239  1259.109131  680.924133
# 240  1031.156860  647.430664
#
# [241 rows x 2 columns]

# %%
error = (y_test -  y_predict)
error.hist(bins = 100, figsize = (12, 5))
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'중식계'}>,
#         <AxesSubplot:title={'center':'석식계'}>]], dtype=object)

# %%
fig, axes = plt.subplots(1, 4, figsize= (20, 5))

df_hist_lnch[["mse", "val_mse"]].plot(ax = axes[0])
df_hist_lnch[["mae", "val_mae"]].plot(ax = axes[1])
df_hist_dnr[["mse", "val_mse"]].plot(ax = axes[2])
df_hist_dnr[["mae", "val_mae"]].plot(ax = axes[3])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 5))
_=sns.regplot(x = y_test["중식계"], y = y_predict["중식계"], ax = axes[0])
_=sns.regplot(x = y_test["석식계"], y = y_predict["석식계"], ax = axes[1])

# %%
loss, mae, mse = model_lnch.evaluate(X_test, y_test["중식계"])
print("loss {:5.2f}, mse {:5.2f}, mae {:5.2f}".format(loss, mse, mae))
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 106.6713 - mse: 17228.6738 - mae: 106.6713
# loss 106.67, mse 106.67, mae 17228.67

# %%
loss, mae, mse = model_dnr.evaluate(X_test, y_test["석식계"])
print("loss {:5.2f}, mse {:5.2f}, mae {:5.2f}".format(loss, mse, mae))
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 180.5631 - mse: 42375.7695 - mae: 180.5631
# loss 180.56, mse 180.56, mae 42375.77

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test["중식계"], y_predict["중식계"]), r2_score(y_test["석식계"], y_predict["석식계"]))
# Out:
# 0.6509154130721165 -1.0957868067869816

# %% [markdown]
# ### Random Forest model
# 머신러닝 모델과의 비교를 위해...

# %%
from sklearn.ensemble import RandomForestRegressor
RF_lnch = RandomForestRegressor(random_state = 42, n_estimators = 1000, max_depth = 1000, n_jobs = -1, max_features = 0.8)
RF_dnr = RandomForestRegressor(random_state = 42, n_estimators = 1000, max_depth = 1000, n_jobs = -1, max_features = 0.8)

# %%
RF_lnch.fit(X_train, y_train["중식계"])
RF_dnr.fit(X_train, y_train["석식계"])
# Out:
# RandomForestRegressor(max_depth=1000, max_features=0.8, n_estimators=1000,
#                       n_jobs=-1, random_state=42)

# %%
y_predict_RF = pd.DataFrame(np.column_stack((RF_lnch.predict(X_test), RF_dnr.predict(X_test))), columns = label_names)

# %%
error = (y_test -  y_predict_RF)
error.hist(bins = 100, figsize = (12, 5))
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# array([[<AxesSubplot:title={'center':'중식계'}>,
#         <AxesSubplot:title={'center':'석식계'}>]], dtype=object)

# %%
fig, axes = plt.subplots(1, 2, figsize = (12, 5))
_=sns.regplot(x = y_test["중식계"], y = y_predict_RF["중식계"], ax = axes[0])
_=sns.regplot(x = y_test["석식계"], y = y_predict_RF["석식계"], ax = axes[1])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_predict_RF)
# Out:
# 104.97770746887966

# %%
print(r2_score(y_test["중식계"], y_predict_RF["중식계"]), r2_score(y_test["석식계"], y_predict_RF["석식계"]))
# Out:
# 0.6391561452851912 0.26816073858835476

# %%
fig, axes = plt.subplots(2,1, figsize = (12 , 6))
sns.barplot(x = RF_lnch.feature_importances_, y = X_train.columns.tolist(), ax = axes[0])
sns.barplot(x = RF_dnr.feature_importances_, y = X_train.columns.tolist(), ax = axes[1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 마치며
#
# 재밌는 주제의 데이터 분석이었지만 아직 DNN에 대한 이해가 부족해서인지, 생각보다 모델의 예측 능력이 (Random Forest보다도) 좋지 않아서 조금 답답한 프로젝트였던 것 같다.
# 모델 예측력이 좋으면 모델을 활용한 예측 서비스를 구현해보고 싶었는데, 그렇지 못해서 아쉽고 많은 시행착오를 겪으면서 모델을 개선하는 연습이 필요할 것 같다.
